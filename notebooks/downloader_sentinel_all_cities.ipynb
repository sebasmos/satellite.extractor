# %% [markdown]
# <a href="https://colab.research.google.com/github/sebasmos/satellite.extractor/blob/main/downloader_sentinel_all_cities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
% cd /content/drive/MyDrive/Dengue_prediction
# Out:
# /content/drive/MyDrive/Dengue_prediction

# %% [markdown]
# # Setup

# %%
# !pip install sentinelhub
! pip install sentinelhub --upgrade
# Out:
# Collecting sentinelhub
#   Downloading sentinelhub-3.4.3.tar.gz (201 kB)
#      |████████████████████████████████| 201 kB 4.5 MB/s
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (0.37.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (2.23.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.19.5)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (2021.11.2)
# Collecting pillow<=8.4.0,>=8.3.2
#   Downloading Pillow-8.4.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 56.6 MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (2.8.2)
# Collecting utm
#   Downloading utm-0.7.0.tar.gz (8.7 kB)
# Requirement already satisfied: shapely in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.8.0)
# Collecting boto3
#   Downloading boto3-1.20.35-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 68.1 MB/s
# Collecting botocore
#   Downloading botocore-1.23.35-py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 44.6 MB/s
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 52.6 MB/s
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (3.1.1)
# Requirement already satisfied: requests_oauthlib in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.3.0)
# Collecting aenum>=2.1.4
#   Downloading aenum-3.1.5-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 65.8 MB/s
# Collecting dataclasses-json
#   Downloading dataclasses_json-0.5.6-py3-none-any.whl (25 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (4.62.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from pyproj>=2.2.0->sentinelhub) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sentinelhub) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sentinelhub) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sentinelhub) (2.10)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.6 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 76.3 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->sentinelhub) (1.15.0)
# Collecting marshmallow<4.0.0,>=3.3.0
#   Downloading marshmallow-3.14.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.4 MB/s
# Collecting typing-inspect>=0.4.0
#   Downloading typing_inspect-0.7.1-py3-none-any.whl (8.4 kB)
# Collecting marshmallow-enum<2.0.0,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->sentinelhub) (3.10.0.2)
# Building wheels for collected packages: sentinelhub, utm
#   Building wheel for sentinelhub (setup.py) ... done
#   Created wheel for sentinelhub: filename=sentinelhub-3.4.3-py3-none-any.whl size=216373 sha256=59d92b7e391df462e61722f0f8e970693181594421b9d296ec15331e101a7c48
#   Stored in directory: /root/.cache/pip/wheels/d8/50/c8/af0007ff3e658ea0b9b1081523a7f6a8686e93fe20e89d59fb
#   Building wheel for utm (setup.py) ... done
#   Created wheel for utm: filename=utm-0.7.0-py3-none-any.whl size=6108 sha256=09d8df5283a3fec66db04d121ae135b3b57a724a1ec4ca4248ca1fa53ae62c2c
#   Stored in directory: /root/.cache/pip/wheels/a5/b0/12/7ee4fdb0f9fbb4157100bd02390436ed5d58ebfd3c6d6a0886
# Successfully built sentinelhub utm
# Installing collected packages: urllib3, jmespath, mypy-extensions, marshmallow, botocore, typing-inspect, s3transfer, marshmallow-enum, utm, pyproj, pillow, dataclasses-json, boto3, aenum, sentinelhub
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed aenum-3.1.5 boto3-1.20.35 botocore-1.23.35 dataclasses-json-0.5.6 jmespath-0.10.0 marshmallow-3.14.1 marshmallow-enum-1.5.1 mypy-extensions-0.4.3 pillow-8.4.0 pyproj-3.2.1 s3transfer-0.5.0 sentinelhub-3.4.3 typing-inspect-0.7.1 urllib3-1.25.11 utm-0.7.0
# Requirement already satisfied: sentinelhub in /usr/local/lib/python3.7/dist-packages (3.4.3)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (3.2.1)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (0.5.6)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (2.23.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.3.0)
# Requirement already satisfied: pillow<=8.4.0,>=8.3.2 in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (8.4.0)
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (3.1.1)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.20.35)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.19.5)
# Requirement already satisfied: shapely in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.8.0)
# Requirement already satisfied: botocore in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.23.35)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (2021.11.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (7.1.2)
# Requirement already satisfied: aenum>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (3.1.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (2.8.2)
# Requirement already satisfied: utm in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (0.7.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (4.62.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (0.37.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from pyproj>=2.2.0->sentinelhub) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sentinelhub) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sentinelhub) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sentinelhub) (1.25.11)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3->sentinelhub) (0.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->sentinelhub) (0.10.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->sentinelhub) (1.15.0)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->sentinelhub) (0.7.1)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->sentinelhub) (1.5.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->sentinelhub) (3.14.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->sentinelhub) (3.10.0.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->sentinelhub) (0.4.3)

# %%
% cd /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/
#!git clone https://github.com/sentinel-hub/sentinelhub-py.git
# Out:
# /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel

# %%
% cd /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/sentinelhub-py
# Install dependencies
! python setup.py build
! python setup.py install
! pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/sentinelhub-py
# running build
# running build_py
# running egg_info
# writing sentinelhub.egg-info/PKG-INFO
# writing dependency_links to sentinelhub.egg-info/dependency_links.txt
# writing entry points to sentinelhub.egg-info/entry_points.txt
# writing requirements to sentinelhub.egg-info/requires.txt
# writing top-level names to sentinelhub.egg-info/top_level.txt
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE.md'
# writing manifest file 'sentinelhub.egg-info/SOURCES.txt'
# running install
# running bdist_egg
# running egg_info
# writing sentinelhub.egg-info/PKG-INFO
# writing dependency_links to sentinelhub.egg-info/dependency_links.txt
# writing entry points to sentinelhub.egg-info/entry_points.txt
# writing requirements to sentinelhub.egg-info/requires.txt
# writing top-level names to sentinelhub.egg-info/top_level.txt
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE.md'
# writing manifest file 'sentinelhub.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_catalog.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/aws_safe.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/aws.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/testing_utils.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/__init__.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/io_utils.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sh_utils.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/geopedia.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/opensearch.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/data_collections.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/geo_utils.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/os_utils.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_batch.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_rate_limit.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/.utmzones.geojson -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/areas.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/exceptions.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/commands.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_base_api.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_statistical.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/data_request.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/_version.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/time_utils.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/data_collections_bands.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/ogc.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/decoding.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_byoc.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/geometry.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_request.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/constants.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/config.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/fis.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_session.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/config.json -> build/bdist.linux-x86_64/egg/sentinelhub
# creating build/bdist.linux-x86_64/egg/sentinelhub/download
# copying build/lib/sentinelhub/download/request.py -> build/bdist.linux-x86_64/egg/sentinelhub/download
# copying build/lib/sentinelhub/download/sentinelhub_statistical_client.py -> build/bdist.linux-x86_64/egg/sentinelhub/download
# copying build/lib/sentinelhub/download/sentinelhub_client.py -> build/bdist.linux-x86_64/egg/sentinelhub/download
# copying build/lib/sentinelhub/download/aws_client.py -> build/bdist.linux-x86_64/egg/sentinelhub/download
# copying build/lib/sentinelhub/download/handlers.py -> build/bdist.linux-x86_64/egg/sentinelhub/download
# copying build/lib/sentinelhub/download/__init__.py -> build/bdist.linux-x86_64/egg/sentinelhub/download
# copying build/lib/sentinelhub/download/client.py -> build/bdist.linux-x86_64/egg/sentinelhub/download
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_catalog.py to sentinelhub_catalog.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/aws_safe.py to aws_safe.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/aws.py to aws.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/testing_utils.py to testing_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/io_utils.py to io_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sh_utils.py to sh_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/geopedia.py to geopedia.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/opensearch.py to opensearch.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/data_collections.py to data_collections.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/geo_utils.py to geo_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/os_utils.py to os_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_batch.py to sentinelhub_batch.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_rate_limit.py to sentinelhub_rate_limit.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/areas.py to areas.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/exceptions.py to exceptions.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/commands.py to commands.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_base_api.py to sentinelhub_base_api.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_statistical.py to sentinelhub_statistical.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/data_request.py to data_request.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/_version.py to _version.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/time_utils.py to time_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/data_collections_bands.py to data_collections_bands.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/ogc.py to ogc.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/decoding.py to decoding.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_byoc.py to sentinelhub_byoc.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/geometry.py to geometry.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_request.py to sentinelhub_request.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/constants.py to constants.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/config.py to config.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/fis.py to fis.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_session.py to sentinelhub_session.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/download/request.py to request.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/download/sentinelhub_statistical_client.py to sentinelhub_statistical_client.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/download/sentinelhub_client.py to sentinelhub_client.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/download/aws_client.py to aws_client.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/download/handlers.py to handlers.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/download/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/download/client.py to client.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying sentinelhub.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sentinelhub.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sentinelhub.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sentinelhub.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sentinelhub.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sentinelhub.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sentinelhub.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating 'dist/sentinelhub-3.4.1-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing sentinelhub-3.4.1-py3.7.egg
# creating /usr/local/lib/python3.7/dist-packages/sentinelhub-3.4.1-py3.7.egg
# Extracting sentinelhub-3.4.1-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding sentinelhub 3.4.1 to easy-install.pth file
# Installing sentinelhub script to /usr/local/bin
# Installing sentinelhub.aws script to /usr/local/bin
# Installing sentinelhub.config script to /usr/local/bin
# Installing sentinelhub.download script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/sentinelhub-3.4.1-py3.7.egg
# Processing dependencies for sentinelhub==3.4.1
# Searching for tqdm==4.62.3
# Best match: tqdm 4.62.3
# Adding tqdm 4.62.3 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for dataclasses-json==0.5.6
# Best match: dataclasses-json 0.5.6
# Adding dataclasses-json 0.5.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for aenum==3.1.5
# Best match: aenum 3.1.5
# Adding aenum 3.1.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for requests-oauthlib==1.3.0
# Best match: requests-oauthlib 1.3.0
# Adding requests-oauthlib 1.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for oauthlib==3.1.1
# Best match: oauthlib 3.1.1
# Adding oauthlib 3.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pyproj==3.2.1
# Best match: pyproj 3.2.1
# Adding pyproj 3.2.1 to easy-install.pth file
# Installing pyproj script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for botocore==1.23.35
# Best match: botocore 1.23.35
# Adding botocore 1.23.35 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for boto3==1.20.35
# Best match: boto3 1.20.35
# Adding boto3 1.20.35 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Shapely==1.8.0
# Best match: Shapely 1.8.0
# Adding Shapely 1.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for utm==0.7.0
# Best match: utm 0.7.0
# Adding utm 0.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Pillow==8.4.0
# Best match: Pillow 8.4.0
# Adding Pillow 8.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for tifffile==2021.11.2
# Best match: tifffile 2021.11.2
# Adding tifffile 2021.11.2 to easy-install.pth file
# Installing lsm2bin script to /usr/local/bin
# Installing tiff2fsspec script to /usr/local/bin
# Installing tiffcomment script to /usr/local/bin
# Installing tifffile script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for numpy==1.19.5
# Best match: numpy 1.19.5
# Adding numpy 1.19.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.7 script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for click==7.1.2
# Best match: click 7.1.2
# Adding click 7.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for requests==2.23.0
# Best match: requests 2.23.0
# Adding requests 2.23.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for wheel==0.37.1
# Best match: wheel 0.37.1
# Adding wheel 0.37.1 to easy-install.pth file
# Installing wheel script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for marshmallow-enum==1.5.1
# Best match: marshmallow-enum 1.5.1
# Adding marshmallow-enum 1.5.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for typing-inspect==0.7.1
# Best match: typing-inspect 0.7.1
# Adding typing-inspect 0.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for marshmallow==3.14.1
# Best match: marshmallow 3.14.1
# Adding marshmallow 3.14.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for certifi==2021.10.8
# Best match: certifi 2021.10.8
# Adding certifi 2021.10.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for jmespath==0.10.0
# Best match: jmespath 0.10.0
# Adding jmespath 0.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for urllib3==1.25.11
# Best match: urllib3 1.25.11
# Adding urllib3 1.25.11 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for s3transfer==0.5.0
# Best match: s3transfer 0.5.0
# Adding s3transfer 0.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for idna==2.10
# Best match: idna 2.10
# Adding idna 2.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for mypy-extensions==0.4.3
# Best match: mypy-extensions 0.4.3
# Adding mypy-extensions 0.4.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for typing-extensions==3.10.0.2
# Best match: typing-extensions 3.10.0.2
# Adding typing-extensions 3.10.0.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Finished processing dependencies for sentinelhub==3.4.1
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (0.37.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (2.23.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (1.19.5)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (2021.11.2)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (8.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: utm in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: shapely in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 9)) (1.8.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 10)) (1.20.35)
# Requirement already satisfied: botocore in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 11)) (1.23.35)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 12)) (3.2.1)
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 13)) (3.1.1)
# Requirement already satisfied: requests_oauthlib in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: aenum>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 15)) (3.1.5)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 16)) (0.5.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 17)) (4.62.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->-r requirements.txt (line 2)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->-r requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->-r requirements.txt (line 2)) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->-r requirements.txt (line 2)) (2021.10.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->-r requirements.txt (line 7)) (1.15.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->-r requirements.txt (line 10)) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3->-r requirements.txt (line 10)) (0.5.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->-r requirements.txt (line 16)) (3.14.1)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->-r requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->-r requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->-r requirements.txt (line 16)) (3.10.0.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->-r requirements.txt (line 16)) (0.4.3)

# %%
% cd /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel
# Out:
# /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel

# %%
import shutil
# !shutil.rmtree('satellite.extractor')
# !git clone https://github.com/sebasmos/satellite.extractor.git
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `'satellite.extractor''
# /bin/bash: -c: line 0: `shutil.rmtree('satellite.extractor')'
# fatal: destination path 'satellite.extractor' already exists and is not an empty directory.

# %% [markdown]
# # Import functions

# %%
import pandas as pd
import glob
import json
import datetime as dt
from urllib.parse import unquote
from bs4 import BeautifulSoup
import os
import shutil
from sentinelhub import SHConfig
import datetime
import numpy as np
import matplotlib.pyplot as plt
import sys
from datetime import timedelta
sys.path.insert(0,'..') 
from sentinelhub import MimeType, CRS, BBox, SentinelHubRequest, SentinelHubDownloadClient, DataCollection, bbox_to_dimensions, DownloadRequest
# !pip install epiweeks
from epiweeks import Week, Year
from datetime import date
import glob, shutil
# Out:
# Collecting epiweeks
#   Downloading epiweeks-2.1.3-py3-none-any.whl (5.9 kB)
# Installing collected packages: epiweeks
# Successfully installed epiweeks-2.1.3

# %%
# !ls
# Out:
#  csv
# 'DATASETS - DECEMBER'
#  downloader_sentinel_5_cities.ipynb
#  downloader_sentinel_all_cities.ipynb
#  satellite.extractor
#  satellite_imagery_medellin_2015_2018_colab.ipynb
#  Sentinel_Data_Medellin
#  sentinelhub-py

# %%
% cd /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor
# !ls
# Out:
# /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor
# bands_analysis.ipynb	   extractor.py  requirements.txt
# borrar.py		   __init__.py	 satellite.extractor
# coordinates.txt		   linux	 sentinelhub
# Dockerfile		   __pycache__	 setup.py
# downloader_sentinel.ipynb  README.md

# %%
from linux.request_multiple_images_linux import download_multiple_images
from linux.request_multiple_images_linux import get_folder_ID
from linux.rename_linux import get_request_individual
from extractor import get_images

# %%
# !pwd
# Out:
# /content/drive/My Drive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor

# %%
# !ls
# Out:
# bands_analysis.ipynb	   extractor.py  requirements.txt
# borrar.py		   __init__.py	 satellite.extractor
# coordinates.txt		   linux	 sentinelhub
# Dockerfile		   __pycache__	 setup.py
# downloader_sentinel.ipynb  README.md

# %% [markdown]
# # All cities - example

# %%
# Define the range of years
img_format = "tiff"
'''
    # REAL DATA FOR COLOMBIA
    initial_year = 2015
    end_year = 2018
    years = list(range(initial_year,end_year))
    first_2015_week = 44
    end_year = 2020
    start_2015 = Week(initial_year,first_2015_week).startdate()
    weeks_2015 = list(range(first_2015_week, 53))
    weeks = list(range(1,53))
    
    # TESTING DATA
    
    initial_year = 2017
    end_year = 2018
    years = list(range(initial_year,end_year))
    first_2015_week = 44
    end_year = 2018
    start_2015 = Week(initial_year,first_2015_week).startdate()
    weeks_2015 = list(range(first_2015_week, 53))
    weeks = list(range(1,10))
'''
    
# REAL DATA FOR COLOMBIA
initial_year = 2018
end_year = 2018
years = list(range(initial_year,end_year+1))# +1 to consider 2018
first_2015_week = 44
end_year = 2020
start_2015 = Week(initial_year,first_2015_week).startdate()
weeks_2015 = list(range(first_2015_week, 53))
weeks = list(range(1,53))

# path to municipalities
path_csv = "/content/drive/MyDrive/Dengue_prediction/csv/coordinates720_all_municipalities.csv"
dict_coordinates =  pd.read_csv(path_csv)
#dict_coordinates = dict_coordinates[:5]
print(f"Considering batch # {len(dict_coordinates)}")
dict_coordinates = dict(zip(dict_coordinates['Municipality code'], dict_coordinates.square))
    
    
coordenadas = []
municipality = []
for k, v in dict_coordinates.items():
        municipality.append(k)
        res = [float(value) for value in v[1:-1].split(', ')]
        res = np.array(res)
        coordenadas.append(res)
        
columns_names = {'municipalities':municipality, 
                 'coordinates': coordenadas}
df = pd.DataFrame(data=columns_names)
        
new_coord = dict((columns_names))
    
# Define the range of years
img_format = "tiff"
# Out:
# Considering batch # 5

# %%
years
# Out:
# [2018]

# %% [markdown]
# Data is requested and stored in API Sentinelhub format and then it will be moved to a local folder with the correct format.

# %%
root_images = "/data/"
       
temporal_path = os.path.abspath(os.getcwd()) + root_images  
    
if not os.path.isdir(temporal_path):
    os.makedirs(temporal_path)
    print(f"Creating temporal data folder in {temporal_path}")

num = len(new_coord["municipalities"])
        
print(f"Number of cities: {num}")
# Out:
# Creating temporal data folder in /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/data/
# Number of cities: 5

# %%
for i in range(num):  
    print(f"City: {new_coord['municipalities'][i]} - Coordinates: {new_coord['coordinates'][i]}")	    	

    current_coor = list(new_coord["coordinates"][i])
        
    city_str = "DATASET" + "/" + str(new_coord['municipalities'][i])
    	
    if not os.path.exists(city_str):
  	  os.makedirs(city_str)
    	  
  # Download images on given range
    get_images(new_coord, current_coor, years, weeks, weeks_2015, img_format, root_images, CLIENT_ID, CLIENT_SECRET)

  # Move to structured folder in DATASETS
    root_images_store = "." + root_images
    dataset_store = "./" + city_str
    for root, dirs, files in os.walk(root_images_store, topdown=True):
 	      for name in files:
       		   path = os.path.join(root, name)
       		#print(path)
       		   if img_format in path and not dataset_store in path:
       		       shutil.copy(path, dataset_store)
    		    
images = glob.glob(dataset_store+"/*")

# %%
'''
root_images_store = "." + root_images
dataset_store = "./" + city_str
for root, dirs, files in os.walk(root_images_store, topdown=True):
   for name in files:
   		   path = os.path.join(root, name)
       		#print(path)
   		   if img_format in path and not dataset_store in path:
       		       shutil.copy(path, dataset_store)
    		    
images = glob.glob(dataset_store+"/*")
'''

# %%
#shutil.rmtree("DATASET")
shutil.rmtree("data")

# %% [markdown]
# # Transfer to GCP bucket
#
# https://philipplies.medium.com/transferring-data-from-google-drive-to-google-cloud-storage-using-google-colab-96e088a8c041

# %%
from google.colab import auth
auth.authenticate_user()

# %%
project_id = 'mit-hst-dengue'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://colombia_sebasmos/
# gs://dsrestrepo/
# gs://mit-hst-dengue/

# %%
bucket_name = 'colombia_sebasmos'

# !gsutil -m cp -r /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_final/ gs://{bucket_name}/
# Out:
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_final/76001/image_2015-11-15.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_final/76001/image_2015-11-01.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_final/76001/image_2015-11-22.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_final/76001/image_2015-11-29.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_final/76001/image_2015