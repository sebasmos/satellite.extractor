# %% [markdown]
# <a href="https://colab.research.google.com/github/sebasmos/satellite.extractor/blob/main/downloader_sentinel_5_cities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
% cd /content/drive/MyDrive/Dengue_prediction
# Out:
# /content/drive/MyDrive/Dengue_prediction

# %% [markdown]
# # Setup

# %%
# !pip install sentinelhub
! pip install sentinelhub --upgrade
# Out:
# Collecting sentinelhub
#   Downloading sentinelhub-3.4.3.tar.gz (201 kB)
#      |████████████████████████████████| 201 kB 16.3 MB/s
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (0.37.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (2.23.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.19.5)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (2021.11.2)
# Collecting pillow<=8.4.0,>=8.3.2
#   Downloading Pillow-8.4.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 53.2 MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (2.8.2)
# Collecting utm
#   Downloading utm-0.7.0.tar.gz (8.7 kB)
# Requirement already satisfied: shapely in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.8.0)
# Collecting boto3
#   Downloading boto3-1.20.46-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 71.1 MB/s
# Collecting botocore
#   Downloading botocore-1.23.46-py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 65.3 MB/s
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 52.2 MB/s
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (3.1.1)
# Requirement already satisfied: requests_oauthlib in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.3.0)
# Collecting aenum>=2.1.4
#   Downloading aenum-3.1.8-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 81.2 MB/s
# Collecting dataclasses-json
#   Downloading dataclasses_json-0.5.6-py3-none-any.whl (25 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (4.62.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from pyproj>=2.2.0->sentinelhub) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sentinelhub) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sentinelhub) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sentinelhub) (3.0.4)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 8.3 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 86.8 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->sentinelhub) (1.15.0)
# Collecting marshmallow<4.0.0,>=3.3.0
#   Downloading marshmallow-3.14.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 3.7 MB/s
# Collecting marshmallow-enum<2.0.0,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting typing-inspect>=0.4.0
#   Downloading typing_inspect-0.7.1-py3-none-any.whl (8.4 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->sentinelhub) (3.10.0.2)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Building wheels for collected packages: sentinelhub, utm
#   Building wheel for sentinelhub (setup.py) ... done
#   Created wheel for sentinelhub: filename=sentinelhub-3.4.3-py3-none-any.whl size=216373 sha256=37f01712141f7a7e650a479b2924d63b482003589675cdaab029919b9d16e702
#   Stored in directory: /root/.cache/pip/wheels/d8/50/c8/af0007ff3e658ea0b9b1081523a7f6a8686e93fe20e89d59fb
#   Building wheel for utm (setup.py) ... done
#   Created wheel for utm: filename=utm-0.7.0-py3-none-any.whl size=6108 sha256=afd8cd713d6a7b5d98e7b8f3aa01bbc091693091c322e93181f6d469ca14ac9c
#   Stored in directory: /root/.cache/pip/wheels/a5/b0/12/7ee4fdb0f9fbb4157100bd02390436ed5d58ebfd3c6d6a0886
# Successfully built sentinelhub utm
# Installing collected packages: urllib3, jmespath, mypy-extensions, marshmallow, botocore, typing-inspect, s3transfer, marshmallow-enum, utm, pyproj, pillow, dataclasses-json, boto3, aenum, sentinelhub
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed aenum-3.1.8 boto3-1.20.46 botocore-1.23.46 dataclasses-json-0.5.6 jmespath-0.10.0 marshmallow-3.14.1 marshmallow-enum-1.5.1 mypy-extensions-0.4.3 pillow-8.4.0 pyproj-3.2.1 s3transfer-0.5.0 sentinelhub-3.4.3 typing-inspect-0.7.1 urllib3-1.25.11 utm-0.7.0
# Requirement already satisfied: sentinelhub in /usr/local/lib/python3.7/dist-packages (3.4.3)
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (3.1.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (0.37.1)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (4.62.3)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (0.5.6)
# Requirement already satisfied: shapely in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.8.0)
# Requirement already satisfied: utm in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (0.7.0)
# Requirement already satisfied: pillow<=8.4.0,>=8.3.2 in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (8.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (2.8.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (7.1.2)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.20.46)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (2.23.0)
# Requirement already satisfied: botocore in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (1.23.46)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (3.2.1)
# Requirement already satisfied: aenum>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (3.1.8)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.7/dist-packages (from sentinelhub) (2021.11.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from pyproj>=2.2.0->sentinelhub) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sentinelhub) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sentinelhub) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->sentinelhub) (2.10)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3->sentinelhub) (0.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->sentinelhub) (0.10.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->sentinelhub) (1.15.0)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->sentinelhub) (0.7.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->sentinelhub) (3.14.1)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->sentinelhub) (1.5.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->sentinelhub) (0.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->sentinelhub) (3.10.0.2)

# %%
% cd /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/
#!git clone https://github.com/sentinel-hub/sentinelhub-py.git
# Out:
# /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel

# %%
% cd /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/sentinelhub-py
# Install dependencies
! python setup.py build
! python setup.py install
! pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/sentinelhub-py
# running build
# running build_py
# running egg_info
# writing sentinelhub.egg-info/PKG-INFO
# writing dependency_links to sentinelhub.egg-info/dependency_links.txt
# writing entry points to sentinelhub.egg-info/entry_points.txt
# writing requirements to sentinelhub.egg-info/requires.txt
# writing top-level names to sentinelhub.egg-info/top_level.txt
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE.md'
# writing manifest file 'sentinelhub.egg-info/SOURCES.txt'
# running install
# running bdist_egg
# running egg_info
# writing sentinelhub.egg-info/PKG-INFO
# writing dependency_links to sentinelhub.egg-info/dependency_links.txt
# writing entry points to sentinelhub.egg-info/entry_points.txt
# writing requirements to sentinelhub.egg-info/requires.txt
# writing top-level names to sentinelhub.egg-info/top_level.txt
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE.md'
# writing manifest file 'sentinelhub.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_catalog.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/aws_safe.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/aws.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/testing_utils.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/__init__.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/io_utils.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sh_utils.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/geopedia.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/opensearch.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/data_collections.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/geo_utils.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/os_utils.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_batch.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_rate_limit.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/.utmzones.geojson -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/areas.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/exceptions.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/commands.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_base_api.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_statistical.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/data_request.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/_version.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/time_utils.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/data_collections_bands.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/ogc.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/decoding.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_byoc.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/geometry.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_request.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/constants.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/config.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/fis.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/sentinelhub_session.py -> build/bdist.linux-x86_64/egg/sentinelhub
# copying build/lib/sentinelhub/config.json -> build/bdist.linux-x86_64/egg/sentinelhub
# creating build/bdist.linux-x86_64/egg/sentinelhub/download
# copying build/lib/sentinelhub/download/request.py -> build/bdist.linux-x86_64/egg/sentinelhub/download
# copying build/lib/sentinelhub/download/sentinelhub_statistical_client.py -> build/bdist.linux-x86_64/egg/sentinelhub/download
# copying build/lib/sentinelhub/download/sentinelhub_client.py -> build/bdist.linux-x86_64/egg/sentinelhub/download
# copying build/lib/sentinelhub/download/aws_client.py -> build/bdist.linux-x86_64/egg/sentinelhub/download
# copying build/lib/sentinelhub/download/handlers.py -> build/bdist.linux-x86_64/egg/sentinelhub/download
# copying build/lib/sentinelhub/download/__init__.py -> build/bdist.linux-x86_64/egg/sentinelhub/download
# copying build/lib/sentinelhub/download/client.py -> build/bdist.linux-x86_64/egg/sentinelhub/download
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_catalog.py to sentinelhub_catalog.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/aws_safe.py to aws_safe.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/aws.py to aws.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/testing_utils.py to testing_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/io_utils.py to io_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sh_utils.py to sh_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/geopedia.py to geopedia.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/opensearch.py to opensearch.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/data_collections.py to data_collections.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/geo_utils.py to geo_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/os_utils.py to os_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_batch.py to sentinelhub_batch.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_rate_limit.py to sentinelhub_rate_limit.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/areas.py to areas.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/exceptions.py to exceptions.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/commands.py to commands.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_base_api.py to sentinelhub_base_api.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_statistical.py to sentinelhub_statistical.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/data_request.py to data_request.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/_version.py to _version.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/time_utils.py to time_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/data_collections_bands.py to data_collections_bands.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/ogc.py to ogc.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/decoding.py to decoding.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_byoc.py to sentinelhub_byoc.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/geometry.py to geometry.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_request.py to sentinelhub_request.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/constants.py to constants.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/config.py to config.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/fis.py to fis.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/sentinelhub_session.py to sentinelhub_session.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/download/request.py to request.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/download/sentinelhub_statistical_client.py to sentinelhub_statistical_client.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/download/sentinelhub_client.py to sentinelhub_client.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/download/aws_client.py to aws_client.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/download/handlers.py to handlers.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/download/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sentinelhub/download/client.py to client.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying sentinelhub.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sentinelhub.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sentinelhub.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sentinelhub.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sentinelhub.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sentinelhub.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sentinelhub.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating 'dist/sentinelhub-3.4.1-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing sentinelhub-3.4.1-py3.7.egg
# creating /usr/local/lib/python3.7/dist-packages/sentinelhub-3.4.1-py3.7.egg
# Extracting sentinelhub-3.4.1-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding sentinelhub 3.4.1 to easy-install.pth file
# Installing sentinelhub script to /usr/local/bin
# Installing sentinelhub.aws script to /usr/local/bin
# Installing sentinelhub.config script to /usr/local/bin
# Installing sentinelhub.download script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/sentinelhub-3.4.1-py3.7.egg
# Processing dependencies for sentinelhub==3.4.1
# Searching for tqdm==4.62.3
# Best match: tqdm 4.62.3
# Adding tqdm 4.62.3 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for dataclasses-json==0.5.6
# Best match: dataclasses-json 0.5.6
# Adding dataclasses-json 0.5.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for aenum==3.1.8
# Best match: aenum 3.1.8
# Adding aenum 3.1.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for requests-oauthlib==1.3.0
# Best match: requests-oauthlib 1.3.0
# Adding requests-oauthlib 1.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for oauthlib==3.1.1
# Best match: oauthlib 3.1.1
# Adding oauthlib 3.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pyproj==3.2.1
# Best match: pyproj 3.2.1
# Adding pyproj 3.2.1 to easy-install.pth file
# Installing pyproj script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for botocore==1.23.46
# Best match: botocore 1.23.46
# Adding botocore 1.23.46 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for boto3==1.20.46
# Best match: boto3 1.20.46
# Adding boto3 1.20.46 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Shapely==1.8.0
# Best match: Shapely 1.8.0
# Adding Shapely 1.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for utm==0.7.0
# Best match: utm 0.7.0
# Adding utm 0.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Pillow==8.4.0
# Best match: Pillow 8.4.0
# Adding Pillow 8.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for tifffile==2021.11.2
# Best match: tifffile 2021.11.2
# Adding tifffile 2021.11.2 to easy-install.pth file
# Installing lsm2bin script to /usr/local/bin
# Installing tiff2fsspec script to /usr/local/bin
# Installing tiffcomment script to /usr/local/bin
# Installing tifffile script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for numpy==1.19.5
# Best match: numpy 1.19.5
# Adding numpy 1.19.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.7 script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for click==7.1.2
# Best match: click 7.1.2
# Adding click 7.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for requests==2.23.0
# Best match: requests 2.23.0
# Adding requests 2.23.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for wheel==0.37.1
# Best match: wheel 0.37.1
# Adding wheel 0.37.1 to easy-install.pth file
# Installing wheel script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for marshmallow==3.14.1
# Best match: marshmallow 3.14.1
# Adding marshmallow 3.14.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for typing-inspect==0.7.1
# Best match: typing-inspect 0.7.1
# Adding typing-inspect 0.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for marshmallow-enum==1.5.1
# Best match: marshmallow-enum 1.5.1
# Adding marshmallow-enum 1.5.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for certifi==2021.10.8
# Best match: certifi 2021.10.8
# Adding certifi 2021.10.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for urllib3==1.25.11
# Best match: urllib3 1.25.11
# Adding urllib3 1.25.11 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for jmespath==0.10.0
# Best match: jmespath 0.10.0
# Adding jmespath 0.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for s3transfer==0.5.0
# Best match: s3transfer 0.5.0
# Adding s3transfer 0.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for idna==2.10
# Best match: idna 2.10
# Adding idna 2.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for typing-extensions==3.10.0.2
# Best match: typing-extensions 3.10.0.2
# Adding typing-extensions 3.10.0.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for mypy-extensions==0.4.3
# Best match: mypy-extensions 0.4.3
# Adding mypy-extensions 0.4.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Finished processing dependencies for sentinelhub==3.4.1
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (0.37.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (2.23.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (1.19.5)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (2021.11.2)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (8.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: utm in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: shapely in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 9)) (1.8.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 10)) (1.20.46)
# Requirement already satisfied: botocore in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 11)) (1.23.46)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 12)) (3.2.1)
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 13)) (3.1.1)
# Requirement already satisfied: requests_oauthlib in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: aenum>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 15)) (3.1.8)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 16)) (0.5.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 17)) (4.62.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->-r requirements.txt (line 2)) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->-r requirements.txt (line 2)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->-r requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.0->-r requirements.txt (line 2)) (2021.10.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->-r requirements.txt (line 7)) (1.15.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3->-r requirements.txt (line 10)) (0.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->-r requirements.txt (line 10)) (0.10.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->-r requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->-r requirements.txt (line 16)) (3.14.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->-r requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->-r requirements.txt (line 16)) (3.10.0.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->-r requirements.txt (line 16)) (0.4.3)

# %%
% cd /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel
# Out:
# /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel

# %%
import shutil
# !shutil.rmtree('satellite.extractor')
# !git clone https://github.com/sebasmos/satellite.extractor.git
# Out:
# Cloning into 'satellite.extractor'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 101 (delta 2), reused 0 (delta 0), pack-reused 95
# Receiving objects: 100% (101/101), 36.18 MiB | 16.32 MiB/s, done.
# Resolving deltas: 100% (43/43), done.

# %% [markdown]
# # Import functions

# %%
import pandas as pd
import glob
import json
import datetime as dt
from urllib.parse import unquote
from bs4 import BeautifulSoup
import os
import shutil
from sentinelhub import SHConfig
import datetime
import numpy as np
import matplotlib.pyplot as plt
import sys
from datetime import timedelta
sys.path.insert(0,'..') 
from sentinelhub import MimeType, CRS, BBox, SentinelHubRequest, SentinelHubDownloadClient, DataCollection, bbox_to_dimensions, DownloadRequest
# !pip install epiweeks
from epiweeks import Week, Year
from datetime import date
import glob, shutil
# Out:
# Requirement already satisfied: epiweeks in /usr/local/lib/python3.7/dist-packages (2.1.3)

# %%
# !ls
# Out:
#  csv				        ORGANIZE_old_codes
# 'DATASETS - DECEMBER'		        satellite.extractor
#  downloader_sentinel_5_cities.ipynb     Sentinel_Data_Medellin
#  downloader_sentinel_all_cities.ipynb   sentinelhub-py

# %%
% cd /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor
# !ls
# Out:
# /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor
# bands_analysis.ipynb		      __init__.py
# borrar.py			      linux
# coordinates.txt			      README.md
# Dockerfile			      requirements.txt
# downloader_sentinel_all_cities.ipynb  sentinelhub
# downloader_sentinel.ipynb	      setup.py
# extractor.py

# %%
from linux.request_multiple_images_linux import download_multiple_images
from linux.request_multiple_images_linux import get_folder_ID
from linux.rename_linux import get_request_individual
from extractor import get_images

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor

# %%
# !ls
# Out:
# bands_analysis.ipynb		      __init__.py
# borrar.py			      linux
# coordinates.txt			      __pycache__
# Dockerfile			      README.md
# downloader_sentinel_all_cities.ipynb  requirements.txt
# downloader_sentinel.ipynb	      sentinelhub
# extractor.py			      setup.py

# %% [markdown]
# # 5 cities

# %%
dic = {'Cali': [-76.55323133405957, 3.4062672204498083, -76.4860619546151, 3.473745747318065],
    	    'Medellín': [-75.60847058045997, 6.210967220073269, -75.5410220422612, 6.278445747318065],
    	    'Villavicencio': [-73.66295855834497, 4.108767220355771, -73.59573458823247, 4.176245747318064],
    	    'Cúcuta': [-72.53849203162315, 7.873767219848251, -72.47080007014465, 7.941245747318064],
    	    'Ibagué': [-75.2341715228093, 4.404067220316198, -75.16692155913864, 4.471545747318066]}

# %%
img_format = "tiff"
'''
    # REAL DATA FOR COLOMBIA
    initial_year = 2015
    end_year = 2018
    years = list(range(initial_year,end_year))
    first_2015_week = 44
    end_year = 2020
    start_2015 = Week(initial_year,first_2015_week).startdate()
    weeks_2015 = list(range(first_2015_week, 53))
    weeks = list(range(1,53))
    
    # TESTING DATA
    
    initial_year = 2017
    end_year = 2018
    years = list(range(initial_year,end_year))
    first_2015_week = 44
    end_year = 2018
    start_2015 = Week(initial_year,first_2015_week).startdate()
    weeks_2015 = list(range(first_2015_week, 53))
    weeks = list(range(1,10))
'''
    
# Define the range of years
initial_year = 2015
end_year = 2019
years = list(range(initial_year,end_year))
first_2015_week = 44

start_2015 = Week(initial_year,first_2015_week).startdate()

weeks_2015 = list(range(first_2015_week, 53))
weeks = list(range(1,53))


root_images = "/data/"
       
temporal_path = os.path.abspath(os.getcwd()) + root_images  
    
if not os.path.isdir(temporal_path):
    os.makedirs(temporal_path)
    print("Creating temporal data folder")
        
print(f"Number of cities: {len(dic)}")
print(f"Range: {years}")
print(f"Weeks 2015: {weeks_2015}")
# Out:
# Number of cities: 5
# Range: [2015, 2016, 2017, 2018]
# Weeks 2015: [44, 45, 46, 47, 48, 49, 50, 51, 52]

# %%
def get_images(coordenates, years, weeks, weeks_2015, img_format, root_images, CLIENT_ID, CLIENT_SECRET):
    # Download data
    folder_path = ""
    for year in years:
        if year == 2015:
            for week in weeks_2015:
                print(f"Year: {year} - week: {week}")
                # Set starting date for given year based on 
                start = Week(year, week).startdate()
                # Download individual images
                download_multiple_images(coordenates, start, str(year), CLIENT_ID, CLIENT_SECRET)
                # Obtain ID as the last-obtained response.tiff file, "real-time"
                folder_path = get_folder_ID(root_images, img_format)
                # Rename image based on JSON timestamp filter 
                dates = get_request_individual(folder_path+"/request.json", img_format)
                # Clean folders which contain black images
                path_to_blank_ids  = "." + root_images + "/" + str(year) + "/*/*" 
                ids = glob.glob(path_to_blank_ids)
                for idx in ids:
                    if "response" in idx:
                        folder_path = idx.replace("/" + "response." + img_format, "")
                        #print(folder_path)
                        shutil.rmtree(folder_path)
                ids = glob.glob(path_to_blank_ids)
                #print("ids available: ", ids)
                        
                #flag =  [idx if ("response" in idx) for idx in ids]
        #elif year ==2016:
        else:
            for week in weeks:
                print(f"Year: {year} - week: {week}")
                # Set starting date for given year based on 
                start = Week(year, week).startdate()
                # Download individual images
                download_multiple_images(coordenates, start, str(year), CLIENT_ID, CLIENT_SECRET)
                # Obtain ID as the last-obtained response.tiff file, "real-time"
                folder_path = get_folder_ID(root_images, img_format)
                # Rename image based on JSON timestamp filter 
                dates = get_request_individual(folder_path+"/request.json", img_format)
                # Clean folders which contain black images
                path_to_blank_ids  = "." + root_images + "/" + str(year) + "/*/*" 
                ids = glob.glob(path_to_blank_ids)
                for idx in ids:
                    if "response" in idx:
                        folder_path = idx.replace("/" + "response." + img_format, "")
                        print(folder_path)
                        shutil.rmtree(folder_path)
                ids = glob.glob(path_to_blank_ids)

# %%
for i in dic: 
    print(f"City: {i} - Coordinates: {dic[i]}")	
      
    current_coor = dic[i]
        
    city_str = "DATASET" + "/" + str(i)
        
    if not os.path.exists(city_str):
        os.makedirs(city_str)
    
    # Download images on given range
    get_images(current_coor, years, weeks, weeks_2015, img_format, root_images, CLIENT_ID, CLIENT_SECRET)
      
    # Move to structured folder in DATASETS
    root_images_store = "." + root_images
    dataset_store = "./" + city_str
    for root, dirs, files in os.walk(root_images_store, topdown=True):
        for name in files:
          path = os.path.join(root, name)
          #print(path)
          if img_format in path and not dataset_store in path:
              shutil.copy(path, dataset_store)
              
images = glob.glob(dataset_store+"/*")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Requested week slot: 02/18/2018 - 02/25/2018
# Ended downloading
# image_2018-02-18
# ./data/2018/d9af0969090a0331592737807faa6ef1/response.tiff renamed to ./data/2018/d9af0969090a0331592737807faa6ef1/image_2018-02-18.tiff
# Year: 2018 - week: 9
# Requested week slot: 02/25/2018 - 03/04/2018
# Ended downloading
# image_2018-02-25
# ./data/2018/948f4c94a00810ce3966eb0350c53eba/response.tiff renamed to ./data/2018/948f4c94a00810ce3966eb0350c53eba/image_2018-02-25.tiff
# Year: 2018 - week: 10
# Requested week slot: 03/04/2018 - 03/11/2018
# Ended downloading
# image_2018-03-04
# ./data/2018/b8d8956298aa3e572b3e9de973d3ce79/response.tiff renamed to ./data/2018/b8d8956298aa3e572b3e9de973d3ce79/image_2018-03-04.tiff
# Year: 2018 - week: 11
# Requested week slot: 03/11/2018 - 03/18/2018
# Ended downloading
# image_2018-03-11
# ./data/2018/69ca032dcf862b8dcd538847f0f0e846/response.tiff renamed to ./data/2018/69ca032dcf862b8dcd538847f0f0e846/image_2018-03-11.tiff
# Year: 2018 - week: 12
# Requested week slot: 03/18/2018 - 03/25/2018
# Ended downloading
# image_2018-03-18
# ./data/2018/eb7e0f052678a5d0d7de3de4b74b3833/response.tiff renamed to ./data/2018/eb7e0f052678a5d0d7de3de4b74b3833/image_2018-03-18.tiff
# Year: 2018 - week: 13
# Requested week slot: 03/25/2018 - 04/01/2018
# Ended downloading
# image_2018-03-25
# ./data/2018/756547f38e218505a7df16d4be9e9078/response.tiff renamed to ./data/2018/756547f38e218505a7df16d4be9e9078/image_2018-03-25.tiff
# Year: 2018 - week: 14
# Requested week slot: 04/01/2018 - 04/08/2018
# Ended downloading
# image_2018-04-01
# ./data/2018/597d7fcb9a604c2aa476f77129a02dfd/response.tiff renamed to ./data/2018/597d7fcb9a604c2aa476f77129a02dfd/image_2018-04-01.tiff
# Year: 2018 - week: 15
# Requested week slot: 04/08/2018 - 04/15/2018
# Ended downloading
# image_2018-04-08
# ./data/2018/d70790c371283249073461f13be56870/response.tiff renamed to ./data/2018/d70790c371283249073461f13be56870/image_2018-04-08.tiff
# Year: 2018 - week: 16
# Requested week slot: 04/15/2018 - 04/22/2018
# Ended downloading
# image_2018-04-15
# ./data/2018/ddf69d979abd7b704e7400072f84f343/response.tiff renamed to ./data/2018/ddf69d979abd7b704e7400072f84f343/image_2018-04-15.tiff
# Year: 2018 - week: 17
# Requested week slot: 04/22/2018 - 04/29/2018
# Ended downloading
# image_2018-04-22
# ./data/2018/05225bb76394c02d8a8d5c007ac2f181/response.tiff renamed to ./data/2018/05225bb76394c02d8a8d5c007ac2f181/image_2018-04-22.tiff
# Year: 2018 - week: 18
# Requested week slot: 04/29/2018 - 05/06/2018
# Ended downloading
# image_2018-04-29
# ./data/2018/c9385b3982213457f49d6a3372f79f65/response.tiff renamed to ./data/2018/c9385b3982213457f49d6a3372f79f65/image_2018-04-29.tiff
# Year: 2018 - week: 19
# Requested week slot: 05/06/2018 - 05/13/2018
# Ended downloading
# image_2018-05-06
# ./data/2018/a491b8fd24c14aa8bb3f5c88584a8045/response.tiff renamed to ./data/2018/a491b8fd24c14aa8bb3f5c88584a8045/image_2018-05-06.tiff
# Year: 2018 - week: 20
# Requested week slot: 05/13/2018 - 05/20/2018
# Ended downloading
# image_2018-05-13
# ./data/2018/32638afaaed90eae9100ecf62cdddb63/response.tiff renamed to ./data/2018/32638afaaed90eae9100ecf62cdddb63/image_2018-05-13.tiff
# Year: 2018 - week: 21
# Requested week slot: 05/20/2018 - 05/27/2018
# Ended downloading
# image_2018-05-20
# ./data/2018/d018f5c4a7039937c791afca3743e48c/response.tiff renamed to ./data/2018/d018f5c4a7039937c791afca3743e48c/image_2018-05-20.tiff
# Year: 2018 - week: 22
# Requested week slot: 05/27/2018 - 06/03/2018
# Ended downloading
# image_2018-05-27
# ./data/2018/b7bca04021cfe6b4ff3b0b7cadbc171b/response.tiff renamed to ./data/2018/b7bca04021cfe6b4ff3b0b7cadbc171b/image_2018-05-27.tiff
# Year: 2018 - week: 23
# Requested week slot: 06/03/2018 - 06/10/2018
# Ended downloading
# image_2018-06-03
# ./data/2018/17133fd94f637b8f7357bfa4674b8163/response.tiff renamed to ./data/2018/17133fd94f637b8f7357bfa4674b8163/image_2018-06-03.tiff
# Year: 2018 - week: 24
# Requested week slot: 06/10/2018 - 06/17/2018
# Ended downloading
# image_2018-06-10
# ./data/2018/dc63e0f04b5761bebeca426354c587f4/response.tiff renamed to ./data/2018/dc63e0f04b5761bebeca426354c587f4/image_2018-06-10.tiff
# Year: 2018 - week: 25
# Requested week slot: 06/17/2018 - 06/24/2018
# Ended downloading
# image_2018-06-17
# ./data/2018/23aeeda8926125ed74091ef422a53c35/response.tiff renamed to ./data/2018/23aeeda8926125ed74091ef422a53c35/image_2018-06-17.tiff
# Year: 2018 - week: 26
# Requested week slot: 06/24/2018 - 07/01/2018
# Ended downloading
# image_2018-06-24
# ./data/2018/e377a2302f936f337442e664f4c28d79/response.tiff renamed to ./data/2018/e377a2302f936f337442e664f4c28d79/image_2018-06-24.tiff
# Year: 2018 - week: 27
# Requested week slot: 07/01/2018 - 07/08/2018
# Ended downloading
# image_2018-07-01
# ./data/2018/9b3c217b9ab7e2a1279be953134a71e8/response.tiff renamed to ./data/2018/9b3c217b9ab7e2a1279be953134a71e8/image_2018-07-01.tiff
# Year: 2018 - week: 28
# Requested week slot: 07/08/2018 - 07/15/2018
# Ended downloading
# image_2018-07-08
# ./data/2018/453e59edfebb97724f99d8ead5123cc2/response.tiff renamed to ./data/2018/453e59edfebb97724f99d8ead5123cc2/image_2018-07-08.tiff
# Year: 2018 - week: 29
# Requested week slot: 07/15/2018 - 07/22/2018
# Ended downloading
# image_2018-07-15
# ./data/2018/f022477f0f5bbf0755167b022b440665/response.tiff renamed to ./data/2018/f022477f0f5bbf0755167b022b440665/image_2018-07-15.tiff
# Year: 2018 - week: 30
# Requested week slot: 07/22/2018 - 07/29/2018
# Ended downloading
# image_2018-07-22
# ./data/2018/f683c2a7be6da2e6ecf754c2d0d1ad7c/response.tiff renamed to ./data/2018/f683c2a7be6da2e6ecf754c2d0d1ad7c/image_2018-07-22.tiff
# Year: 2018 - week: 31
# Requested week slot: 07/29/2018 - 08/05/2018
# Ended downloading
# image_2018-07-29
# ./data/2018/c4511fea9b7ae5fa5523712219a8e578/response.tiff renamed to ./data/2018/c4511fea9b7ae5fa5523712219a8e578/image_2018-07-29.tiff
# Year: 2018 - week: 32
# Requested week slot: 08/05/2018 - 08/12/2018
# Ended downloading
# image_2018-08-05
# ./data/2018/e95ed79ae40fb26c2c0c553a7bda8ac9/response.tiff renamed to ./data/2018/e95ed79ae40fb26c2c0c553a7bda8ac9/image_2018-08-05.tiff
# Year: 2018 - week: 33
# Requested week slot: 08/12/2018 - 08/19/2018
# Ended downloading
# image_2018-08-12
# ./data/2018/87c01bfd48af96befc13bd9a68be2f31/response.tiff renamed to ./data/2018/87c01bfd48af96befc13bd9a68be2f31/image_2018-08-12.tiff
# Year: 2018 - week: 34
# Requested week slot: 08/19/2018 - 08/26/2018
# Ended downloading
# image_2018-08-19
# ./data/2018/19b667fffa7acba16f2118f14c4066c1/response.tiff renamed to ./data/2018/19b667fffa7acba16f2118f14c4066c1/image_2018-08-19.tiff
# Year: 2018 - week: 35
# Requested week slot: 08/26/2018 - 09/02/2018
# Ended downloading
# image_2018-08-26
# ./data/2018/febb547c31efb7277a94c4a6e461eea8/response.tiff renamed to ./data/2018/febb547c31efb7277a94c4a6e461eea8/image_2018-08-26.tiff
# Year: 2018 - week: 36
# Requested week slot: 09/02/2018 - 09/09/2018
# Ended downloading
# image_2018-09-02
# ./data/2018/0da627f197bc736b22ddce54a3d80aaa/response.tiff renamed to ./data/2018/0da627f197bc736b22ddce54a3d80aaa/image_2018-09-02.tiff
# Year: 2018 - week: 37
# Requested week slot: 09/09/2018 - 09/16/2018
# Ended downloading
# image_2018-09-09
# ./data/2018/e6a48b533dd84528158cc5aebef78b29/response.tiff renamed to ./data/2018/e6a48b533dd84528158cc5aebef78b29/image_2018-09-09.tiff
# Year: 2018 - week: 38
# Requested week slot: 09/16/2018 - 09/23/2018
# Ended downloading
# image_2018-09-16
# ./data/2018/08625b6f242730d4e8af50d2bbff56aa/response.tiff renamed to ./data/2018/08625b6f242730d4e8af50d2bbff56aa/image_2018-09-16.tiff
# Year: 2018 - week: 39
# Requested week slot: 09/23/2018 - 09/30/2018
# Ended downloading
# image_2018-09-23
# ./data/2018/ba69c881c05caf6e05ae5bd0971f82e3/response.tiff renamed to ./data/2018/ba69c881c05caf6e05ae5bd0971f82e3/image_2018-09-23.tiff
# Year: 2018 - week: 40
# Requested week slot: 09/30/2018 - 10/07/2018
# Ended downloading
# image_2018-09-30
# ./data/2018/6e3a13f81aef86825901b97604bc2e37/response.tiff renamed to ./data/2018/6e3a13f81aef86825901b97604bc2e37/image_2018-09-30.tiff
# Year: 2018 - week: 41
# Requested week slot: 10/07/2018 - 10/14/2018
# Ended downloading
# image_2018-10-07
# ./data/2018/12818bab26b31abd254038d6a8cdfe7e/response.tiff renamed to ./data/2018/12818bab26b31abd254038d6a8cdfe7e/image_2018-10-07.tiff
# Year: 2018 - week: 42
# Requested week slot: 10/14/2018 - 10/21/2018
# Ended downloading
# image_2018-10-14
# ./data/2018/2f66e0d7b2cfe194df8c65b1d2fcd755/response.tiff renamed to ./data/2018/2f66e0d7b2cfe194df8c65b1d2fcd755/image_2018-10-14.tiff
# Year: 2018 - week: 43
# Requested week slot: 10/21/2018 - 10/28/2018
# Ended downloading
# image_2018-10-21
# ./data/2018/13cac9a05ee394290b680af864cbf55b/response.tiff renamed to ./data/2018/13cac9a05ee394290b680af864cbf55b/image_2018-10-21.tiff
# Year: 2018 - week: 44
# Requested week slot: 10/28/2018 - 11/04/2018
# Ended downloading
# image_2018-10-28
# ./data/2018/3193f8bc290a5f6bdb468bb3d829dccc/response.tiff renamed to ./data/2018/3193f8bc290a5f6bdb468bb3d829dccc/image_2018-10-28.tiff
# Year: 2018 - week: 45
# Requested week slot: 11/04/2018 - 11/11/2018
# Ended downloading
# image_2018-11-04
# ./data/2018/4ce2dfe7b9daed4d01708d8863d792f1/response.tiff renamed to ./data/2018/4ce2dfe7b9daed4d01708d8863d792f1/image_2018-11-04.tiff
# Year: 2018 - week: 46
# Requested week slot: 11/11/2018 - 11/18/2018
# Ended downloading
# image_2018-11-11
# ./data/2018/7861dffd5deaed68dc47531786e4586d/response.tiff renamed to ./data/2018/7861dffd5deaed68dc47531786e4586d/image_2018-11-11.tiff
# Year: 2018 - week: 47
# Requested week slot: 11/18/2018 - 11/25/2018
# Ended downloading
# image_2018-11-18
# ./data/2018/b5e6938d9f99fd26f7126cf1c3c64b74/response.tiff renamed to ./data/2018/b5e6938d9f99fd26f7126cf1c3c64b74/image_2018-11-18.tiff
# Year: 2018 - week: 48
# Requested week slot: 11/25/2018 - 12/02/2018
# Ended downloading
# image_2018-11-25
# ./data/2018/c3590a6943350c7e044903cc6a40cbb5/response.tiff renamed to ./data/2018/c3590a6943350c7e044903cc6a40cbb5/image_2018-11-25.tiff
# Year: 2018 - week: 49
# Requested week slot: 12/02/2018 - 12/09/2018
# Ended downloading
# image_2018-12-02
# ./data/2018/9592e8297236444ab646870431695c4d/response.tiff renamed to ./data/2018/9592e8297236444ab646870431695c4d/image_2018-12-02.tiff
# Year: 2018 - week: 50
# Requested week slot: 12/09/2018 - 12/16/2018
# Ended downloading
# image_2018-12-09
# ./data/2018/e843d5a2817e3347cee449a2879e630b/response.tiff renamed to ./data/2018/e843d5a2817e3347cee449a2879e630b/image_2018-12-09.tiff
# Year: 2018 - week: 51
# Requested week slot: 12/16/2018 - 12/23/2018
# Ended downloading
# image_2018-12-16
# ./data/2018/b41d0c261bbf80bf507fd9aeb86071fc/response.tiff renamed to ./data/2018/b41d0c261bbf80bf507fd9aeb86071fc/image_2018-12-16.tiff
# Year: 2018 - week: 52
# Requested week slot: 12/23/2018 - 12/30/2018
# Ended downloading
# image_2018-12-23
# ./data/2018/29ec3a7f89f558ca75b997b214249758/response.tiff renamed to ./data/2018/29ec3a7f89f558ca75b997b214249758/image_2018-12-23.tiff
# City: Villavicencio - Coordinates: [-73.66295855834497, 4.108767220355771, -73.59573458823247, 4.176245747318064]
# Year: 2015 - week: 44
# Requested week slot: 11/01/2015 - 11/08/2015
# Ended downloading
# Image empty:  0
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# Slot corrected to:  [(datetime.date(2015, 11, 1), datetime.date(2015, 11, 28))]
# image_2015-11-01
# ./data/2015/25d57b55aba372f102c9c17679b066e0/response.tiff renamed to ./data/2015/25d57b55aba372f102c9c17679b066e0/image_2015-11-01.tiff
# Year: 2015 - week: 45
# Requested week slot: 11/08/2015 - 11/15/2015
# Ended downloading
# Image empty:  0
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# Slot corrected to:  [(datetime.date(2015, 11, 8), datetime.date(2015, 11, 28))]
# image_2015-11-08
# ./data/2015/4ff169ab008f808ed8a01fd1227dbce1/response.tiff renamed to ./data/2015/4ff169ab008f808ed8a01fd1227dbce1/image_2015-11-08.tiff
# Year: 2015 - week: 46
# Requested week slot: 11/15/2015 - 11/22/2015
# Ended downloading
# Image empty:  0
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# Slot corrected to:  [(datetime.date(2015, 11, 15), datetime.date(2015, 11, 28))]
# image_2015-11-15
# ./data/2015/808eeb3d12f8c1e799ec65a5b96a2047/response.tiff renamed to ./data/2015/808eeb3d12f8c1e799ec65a5b96a2047/image_2015-11-15.tiff
# Year: 2015 - week: 47
# Requested week slot: 11/22/2015 - 11/29/2015
# Ended downloading
# image_2015-11-22
# ./data/2015/fa395a2e2fe10b34fcd5e52cbfcb99b5/response.tiff renamed to ./data/2015/fa395a2e2fe10b34fcd5e52cbfcb99b5/image_2015-11-22.tiff
# Year: 2015 - week: 48
# Requested week slot: 11/29/2015 - 12/06/2015
# Ended downloading
# Image empty:  0
# This image is being replaced..
# This image is being replaced..
# Slot corrected to:  [(datetime.date(2015, 11, 29), datetime.date(2015, 12, 8))]
# image_2015-11-29
# ./data/2015/5cdbe066ce8cbb7b638c309693a047cd/response.tiff renamed to ./data/2015/5cdbe066ce8cbb7b638c309693a047cd/image_2015-11-29.tiff
# Year: 2015 - week: 49
# Requested week slot: 12/06/2015 - 12/13/2015
# Ended downloading
# image_2015-12-06
# ./data/2015/f60b0d80e0a7ee7af491148d44dacc90/response.tiff renamed to ./data/2015/f60b0d80e0a7ee7af491148d44dacc90/image_2015-12-06.tiff
# Year: 2015 - week: 50
# Requested week slot: 12/13/2015 - 12/20/2015
# Ended downloading
# image_2015-12-13
# ./data/2015/7c4a4835ab3b2ce5aa3fb5e74313bc9d/response.tiff renamed to ./data/2015/7c4a4835ab3b2ce5aa3fb5e74313bc9d/image_2015-12-13.tiff
# Year: 2015 - week: 51
# Requested week slot: 12/20/2015 - 12/27/2015
# Ended downloading
# image_2015-12-20
# ./data/2015/21026d5cdaf35e361099a036574f6767/response.tiff renamed to ./data/2015/21026d5cdaf35e361099a036574f6767/image_2015-12-20.tiff
# Year: 2015 - week: 52
# Requested week slot: 12/27/2015 - 01/03/2016
# Ended downloading
# image_2015-12-27
# ./data/2015/8d66a844db08f3aa2eddeb720ae0cb9b/response.tiff renamed to ./data/2015/8d66a844db08f3aa2eddeb720ae0cb9b/image_2015-12-27.tiff
# Year: 2016 - week: 1
# Requested week slot: 01/03/2016 - 01/10/2016
# Ended downloading
# image_2016-01-03
# ./data/2016/cf410a1300925020eb34fb39aded13a8/response.tiff renamed to ./data/2016/cf410a1300925020eb34fb39aded13a8/image_2016-01-03.tiff
# Year: 2016 - week: 2
# Requested week slot: 01/10/2016 - 01/17/2016
# Ended downloading
# image_2016-01-10
# ./data/2016/4bdde20257ea22aae698ee5c42a6789a/response.tiff renamed to ./data/2016/4bdde20257ea22aae698ee5c42a6789a/image_2016-01-10.tiff
# Year: 2016 - week: 3
# Requested week slot: 01/17/2016 - 01/24/2016
# Ended downloading
# image_2016-01-17
# ./data/2016/76ac03628a36058cd38338734d6763e4/response.tiff renamed to ./data/2016/76ac03628a36058cd38338734d6763e4/image_2016-01-17.tiff
# Year: 2016 - week: 4
# Requested week slot: 01/24/2016 - 01/31/2016
# Ended downloading
# image_2016-01-24
# ./data/2016/7035f6a2510589fdb27fbcb1b4ef0ab1/response.tiff renamed to ./data/2016/7035f6a2510589fdb27fbcb1b4ef0ab1/image_2016-01-24.tiff
# Year: 2016 - week: 5
# Requested week slot: 01/31/2016 - 02/07/2016
# Ended downloading
# image_2016-01-31
# ./data/2016/b368a22fa2d2ba351b37d2aaa5c437b5/response.tiff renamed to ./data/2016/b368a22fa2d2ba351b37d2aaa5c437b5/image_2016-01-31.tiff
# Year: 2016 - week: 6
# Requested week slot: 02/07/2016 - 02/14/2016
# Ended downloading
# image_2016-02-07
# ./data/2016/8f550b786abc79827671d538af978be3/response.tiff renamed to ./data/2016/8f550b786abc79827671d538af978be3/image_2016-02-07.tiff
# Year: 2016 - week: 7
# Requested week slot: 02/14/2016 - 02/21/2016
# Ended downloading
# image_2016-02-14
# ./data/2016/79dbdf04e3a47a4cdcc026c874cfbe76/response.tiff renamed to ./data/2016/79dbdf04e3a47a4cdcc026c874cfbe76/image_2016-02-14.tiff
# Year: 2016 - week: 8
# Requested week slot: 02/21/2016 - 02/28/2016
# Ended downloading
# Image empty:  0
# This image is being replaced..
# Slot corrected to:  [(datetime.date(2016, 2, 21), datetime.date(2016, 2, 29))]
# image_2016-02-21
# ./data/2016/690435bb8aa167e3b1105ca15aba1dcd/response.tiff renamed to ./data/2016/690435bb8aa167e3b1105ca15aba1dcd/image_2016-02-21.tiff
# ./data//2016/df5e7ed901327f7159e1bac832cd1ef2
# Year: 2016 - week: 9
# Requested week slot: 02/28/2016 - 03/06/2016
# Ended downloading
# image_2016-02-28
# ./data/2016/cef6381b2a43fab8e1efd5e777b0df45/response.tiff renamed to ./data/2016/cef6381b2a43fab8e1efd5e777b0df45/image_2016-02-28.tiff
# Year: 2016 - week: 10
# Requested week slot: 03/06/2016 - 03/13/2016
# Ended downloading
# image_2016-03-06
# ./data/2016/ebac0937439617a4a9149f379139ab18/response.tiff renamed to ./data/2016/ebac0937439617a4a9149f379139ab18/image_2016-03-06.tiff
# Year: 2016 - week: 11
# Requested week slot: 03/13/2016 - 03/20/2016
# Ended downloading
# Image empty:  0
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# Slot corrected to:  [(datetime.date(2016, 3, 13), datetime.date(2016, 3, 27))]
# image_2016-03-13
# ./data/2016/72ae2079a4bdcbb26cd728c4d682e090/response.tiff renamed to ./data/2016/72ae2079a4bdcbb26cd728c4d682e090/image_2016-03-13.tiff
# ./data//2016/99f712a908e61933afade0e08b21e420
# ./data//2016/18488bb161e940a4fbbeee2343bbfa44
# ./data//2016/3ffc450c8b8ea7230ce76a10d4228b59
# ./data//2016/21b4c2d2e6825f98b556e6f82d4dab94
# ./data//2016/8d7378d7096c4b35b12d088f638b7b29
# ./data//2016/d688d4d786a6045387364f89e21d79f9
# ./data//2016/f9c602ab93c5f896ee19106fc8f48258
# Year: 2016 - week: 12
# Requested week slot: 03/20/2016 - 03/27/2016
# Ended downloading
# image_2016-03-20
# ./data/2016/879cddedfb04d52b48015cb5f288f790/response.tiff renamed to ./data/2016/879cddedfb04d52b48015cb5f288f790/image_2016-03-20.tiff
# Year: 2016 - week: 13
# Requested week slot: 03/27/2016 - 04/03/2016
# Ended downloading
# image_2016-03-27
# ./data/2016/35ba314a5b1dedf67eebdeae505f7aa9/response.tiff renamed to ./data/2016/35ba314a5b1dedf67eebdeae505f7aa9/image_2016-03-27.tiff
# Year: 2016 - week: 14
# Requested week slot: 04/03/2016 - 04/10/2016
# Ended downloading
# image_2016-04-03
# ./data/2016/5d2d5a5646146d038486797f06c6791a/response.tiff renamed to ./data/2016/5d2d5a5646146d038486797f06c6791a/image_2016-04-03.tiff
# Year: 2016 - week: 15
# Requested week slot: 04/10/2016 - 04/17/2016
# Ended downloading
# image_2016-04-10
# ./data/2016/6469f51c87e30b20983800cef48c803e/response.tiff renamed to ./data/2016/6469f51c87e30b20983800cef48c803e/image_2016-04-10.tiff
# Year: 2016 - week: 16
# Requested week slot: 04/17/2016 - 04/24/2016
# Ended downloading
# image_2016-04-17
# ./data/2016/6be3e4b78f660fbf07a259f31f90be8a/response.tiff renamed to ./data/2016/6be3e4b78f660fbf07a259f31f90be8a/image_2016-04-17.tiff
# Year: 2016 - week: 17
# Requested week slot: 04/24/2016 - 05/01/2016
# Ended downloading
# image_2016-04-24
# ./data/2016/52674c537cd5c5f7f5d6bd942eb6f691/response.tiff renamed to ./data/2016/52674c537cd5c5f7f5d6bd942eb6f691/image_2016-04-24.tiff
# Year: 2016 - week: 18
# Requested week slot: 05/01/2016 - 05/08/2016
# Ended downloading
# image_2016-05-01
# ./data/2016/c7d39dff96664db54f83848de5d51470/response.tiff renamed to ./data/2016/c7d39dff96664db54f83848de5d51470/image_2016-05-01.tiff
# Year: 2016 - week: 19
# Requested week slot: 05/08/2016 - 05/15/2016
# Ended downloading
# image_2016-05-08
# ./data/2016/c76105bc4f0876e8c6a0f52e6e7e209d/response.tiff renamed to ./data/2016/c76105bc4f0876e8c6a0f52e6e7e209d/image_2016-05-08.tiff
# Year: 2016 - week: 20
# Requested week slot: 05/15/2016 - 05/22/2016
# Ended downloading
# image_2016-05-15
# ./data/2016/d1568c5cf3f4fd02afbed6c6752000db/response.tiff renamed to ./data/2016/d1568c5cf3f4fd02afbed6c6752000db/image_2016-05-15.tiff
# Year: 2016 - week: 21
# Requested week slot: 05/22/2016 - 05/29/2016
# Ended downloading
# image_2016-05-22
# ./data/2016/f07120aa8cb6e0db4ac8e50ea4cac072/response.tiff renamed to ./data/2016/f07120aa8cb6e0db4ac8e50ea4cac072/image_2016-05-22.tiff
# Year: 2016 - week: 22
# Requested week slot: 05/29/2016 - 06/05/2016
# Ended downloading
# image_2016-05-29
# ./data/2016/08df6020c855a5f76de5c15191d028dd/response.tiff renamed to ./data/2016/08df6020c855a5f76de5c15191d028dd/image_2016-05-29.tiff
# Year: 2016 - week: 23
# Requested week slot: 06/05/2016 - 06/12/2016
# Ended downloading
# image_2016-06-05
# ./data/2016/0c9c40f962db36571cebad3388e81ed4/response.tiff renamed to ./data/2016/0c9c40f962db36571cebad3388e81ed4/image_2016-06-05.tiff
# Year: 2016 - week: 24
# Requested week slot: 06/12/2016 - 06/19/2016
# Ended downloading
# image_2016-06-12
# ./data/2016/97634ecb5e55ac1eb108bdb60df44830/response.tiff renamed to ./data/2016/97634ecb5e55ac1eb108bdb60df44830/image_2016-06-12.tiff
# Year: 2016 - week: 25
# Requested week slot: 06/19/2016 - 06/26/2016
# Ended downloading
# image_2016-06-19
# ./data/2016/a968fc71e78c72d413a22b888523f5ef/response.tiff renamed to ./data/2016/a968fc71e78c72d413a22b888523f5ef/image_2016-06-19.tiff
# Year: 2016 - week: 26
# Requested week slot: 06/26/2016 - 07/03/2016
# Ended downloading
# image_2016-06-26
# ./data/2016/d54eb3d979edfc6c69897e0e30abff84/response.tiff renamed to ./data/2016/d54eb3d979edfc6c69897e0e30abff84/image_2016-06-26.tiff
# Year: 2016 - week: 27
# Requested week slot: 07/03/2016 - 07/10/2016
# Ended downloading
# image_2016-07-03
# ./data/2016/81136626c1561d689a1ce904632565e6/response.tiff renamed to ./data/2016/81136626c1561d689a1ce904632565e6/image_2016-07-03.tiff
# Year: 2016 - week: 28
# Requested week slot: 07/10/2016 - 07/17/2016
# Ended downloading
# image_2016-07-10
# ./data/2016/3a5d0048aa72138ecf67496f8aae9148/response.tiff renamed to ./data/2016/3a5d0048aa72138ecf67496f8aae9148/image_2016-07-10.tiff
# Year: 2016 - week: 29
# Requested week slot: 07/17/2016 - 07/24/2016
# Ended downloading
# image_2016-07-17
# ./data/2016/294ef3ae6eb2e02b820576210c49439d/response.tiff renamed to ./data/2016/294ef3ae6eb2e02b820576210c49439d/image_2016-07-17.tiff
# Year: 2016 - week: 30
# Requested week slot: 07/24/2016 - 07/31/2016
# Ended downloading
# image_2016-07-24
# ./data/2016/ce71c75f01068b339ebab1a9f13a5321/response.tiff renamed to ./data/2016/ce71c75f01068b339ebab1a9f13a5321/image_2016-07-24.tiff
# Year: 2016 - week: 31
# Requested week slot: 07/31/2016 - 08/07/2016
# Ended downloading
# image_2016-07-31
# ./data/2016/9e5b73ff50fea47462db5d9cb2da6b96/response.tiff renamed to ./data/2016/9e5b73ff50fea47462db5d9cb2da6b96/image_2016-07-31.tiff
# Year: 2016 - week: 32
# Requested week slot: 08/07/2016 - 08/14/2016
# Ended downloading
# image_2016-08-07
# ./data/2016/3096a7ef1617099137a2e21e2fc1a98d/response.tiff renamed to ./data/2016/3096a7ef1617099137a2e21e2fc1a98d/image_2016-08-07.tiff
# Year: 2016 - week: 33
# Requested week slot: 08/14/2016 - 08/21/2016
# Ended downloading
# image_2016-08-14
# ./data/2016/0a1a8311e1231b9de6e5fcf358132b88/response.tiff renamed to ./data/2016/0a1a8311e1231b9de6e5fcf358132b88/image_2016-08-14.tiff
# Year: 2016 - week: 34
# Requested week slot: 08/21/2016 - 08/28/2016
# Ended downloading
# image_2016-08-21
# ./data/2016/2b3f20810f41ff611e22b39e4c8790f5/response.tiff renamed to ./data/2016/2b3f20810f41ff611e22b39e4c8790f5/image_2016-08-21.tiff
# Year: 2016 - week: 35
# Requested week slot: 08/28/2016 - 09/04/2016
# Ended downloading
# image_2016-08-28
# ./data/2016/5332ea2e5ba6dd09ba3adb4feba1504d/response.tiff renamed to ./data/2016/5332ea2e5ba6dd09ba3adb4feba1504d/image_2016-08-28.tiff
# Year: 2016 - week: 36
# Requested week slot: 09/04/2016 - 09/11/2016
# Ended downloading
# image_2016-09-04
# ./data/2016/8c23bd2f1547c8d712f83350f7ef4a97/response.tiff renamed to ./data/2016/8c23bd2f1547c8d712f83350f7ef4a97/image_2016-09-04.tiff
# Year: 2016 - week: 37
# Requested week slot: 09/11/2016 - 09/18/2016
# Ended downloading
# image_2016-09-11
# ./data/2016/dd988a91d6e82e80e8cae506d0f3d0c9/response.tiff renamed to ./data/2016/dd988a91d6e82e80e8cae506d0f3d0c9/image_2016-09-11.tiff
# Year: 2016 - week: 38
# Requested week slot: 09/18/2016 - 09/25/2016
# Ended downloading
# image_2016-09-18
# ./data/2016/e8a6f19f71dd625ce4d2905a51f77682/response.tiff renamed to ./data/2016/e8a6f19f71dd625ce4d2905a51f77682/image_2016-09-18.tiff
# Year: 2016 - week: 39
# Requested week slot: 09/25/2016 - 10/02/2016
# Ended downloading
# image_2016-09-25
# ./data/2016/10c1bb62d84df2eba43e732e924829aa/response.tiff renamed to ./data/2016/10c1bb62d84df2eba43e732e924829aa/image_2016-09-25.tiff
# Year: 2016 - week: 40
# Requested week slot: 10/02/2016 - 10/09/2016
# Ended downloading
# image_2016-10-02
# ./data/2016/08935dcca4c9ced298f174b8bfeecd65/response.tiff renamed to ./data/2016/08935dcca4c9ced298f174b8bfeecd65/image_2016-10-02.tiff
# Year: 2016 - week: 41
# Requested week slot: 10/09/2016 - 10/16/2016
# Ended downloading
# image_2016-10-09
# ./data/2016/7be2c0ccf7862e4dfb675920463b6690/response.tiff renamed to ./data/2016/7be2c0ccf7862e4dfb675920463b6690/image_2016-10-09.tiff
# Year: 2016 - week: 42
# Requested week slot: 10/16/2016 - 10/23/2016
# Ended downloading
# image_2016-10-16
# ./data/2016/f03410213fbeada922992ac3c8b8ad34/response.tiff renamed to ./data/2016/f03410213fbeada922992ac3c8b8ad34/image_2016-10-16.tiff
# Year: 2016 - week: 43
# Requested week slot: 10/23/2016 - 10/30/2016
# Ended downloading
# image_2016-10-23
# ./data/2016/31fcbf3ac589e330bba4bd6c574a7cd1/response.tiff renamed to ./data/2016/31fcbf3ac589e330bba4bd6c574a7cd1/image_2016-10-23.tiff
# Year: 2016 - week: 44
# Requested week slot: 10/30/2016 - 11/06/2016
# Ended downloading
# image_2016-10-30
# ./data/2016/1fb24e7abbaba559c7f901574d2ca564/response.tiff renamed to ./data/2016/1fb24e7abbaba559c7f901574d2ca564/image_2016-10-30.tiff
# Year: 2016 - week: 45
# Requested week slot: 11/06/2016 - 11/13/2016
# Ended downloading
# image_2016-11-06
# ./data/2016/38dc9cca4d73f12ffad499b29e6551d7/response.tiff renamed to ./data/2016/38dc9cca4d73f12ffad499b29e6551d7/image_2016-11-06.tiff
# Year: 2016 - week: 46
# Requested week slot: 11/13/2016 - 11/20/2016
# Ended downloading
# image_2016-11-13
# ./data/2016/b2abd02cdb901048b0c13b4a91873c6d/response.tiff renamed to ./data/2016/b2abd02cdb901048b0c13b4a91873c6d/image_2016-11-13.tiff
# Year: 2016 - week: 47
# Requested week slot: 11/20/2016 - 11/27/2016
# Ended downloading
# image_2016-11-20
# ./data/2016/9d17ad29a95e02585f8991818cece8f0/response.tiff renamed to ./data/2016/9d17ad29a95e02585f8991818cece8f0/image_2016-11-20.tiff
# Year: 2016 - week: 48
# Requested week slot: 11/27/2016 - 12/04/2016
# Ended downloading
# image_2016-11-27
# ./data/2016/096d95d9ef231fead50b69ab8f16b874/response.tiff renamed to ./data/2016/096d95d9ef231fead50b69ab8f16b874/image_2016-11-27.tiff
# Year: 2016 - week: 49
# Requested week slot: 12/04/2016 - 12/11/2016
# Ended downloading
# image_2016-12-04
# ./data/2016/699b0de17a2e1485014791312cbdf56f/response.tiff renamed to ./data/2016/699b0de17a2e1485014791312cbdf56f/image_2016-12-04.tiff
# Year: 2016 - week: 50
# Requested week slot: 12/11/2016 - 12/18/2016
# Ended downloading
# image_2016-12-11
# ./data/2016/d80c693233390c130bf9153034971a6c/response.tiff renamed to ./data/2016/d80c693233390c130bf9153034971a6c/image_2016-12-11.tiff
# Year: 2016 - week: 51
# Requested week slot: 12/18/2016 - 12/25/2016
# Ended downloading
# image_2016-12-18
# ./data/2016/7bd5993325f4b280fcb9ababb6fbb9c2/response.tiff renamed to ./data/2016/7bd5993325f4b280fcb9ababb6fbb9c2/image_2016-12-18.tiff
# Year: 2016 - week: 52
# Requested week slot: 12/25/2016 - 01/01/2017
# Ended downloading
# image_2016-12-25
# ./data/2016/0265829382bd80c745cb00a41a2d48b7/response.tiff renamed to ./data/2016/0265829382bd80c745cb00a41a2d48b7/image_2016-12-25.tiff
# Year: 2017 - week: 1
# Requested week slot: 01/01/2017 - 01/08/2017
# Ended downloading
# image_2017-01-01
# ./data/2017/f74f791c34420924c8c720e6317fbcbd/response.tiff renamed to ./data/2017/f74f791c34420924c8c720e6317fbcbd/image_2017-01-01.tiff
# Year: 2017 - week: 2
# Requested week slot: 01/08/2017 - 01/15/2017
# Ended downloading
# image_2017-01-08
# ./data/2017/189fb4c92299076a58b27ab50e3d5c3f/response.tiff renamed to ./data/2017/189fb4c92299076a58b27ab50e3d5c3f/image_2017-01-08.tiff
# Year: 2017 - week: 3
# Requested week slot: 01/15/2017 - 01/22/2017
# Ended downloading
# Image empty:  0
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# This image is being replaced..
# Slot corrected to:  [(datetime.date(2017, 1, 15), datetime.date(2017, 1, 31))]
# image_2017-01-15
# ./data/2017/bcb07d01aed75d4fc362d3c5f52a6765/response.tiff renamed to ./data/2017/bcb07d01aed75d4fc362d3c5f52a6765/image_2017-01-15.tiff
# ./data//2017/3471dfb07473f0db7bb6b7f4e30e8f97
# ./data//2017/74d7dda5c5c342e39d6baa77aba87a55
# ./data//2017/904041d7445cab095327fdfea3930cd3
# ./data//2017/00ff6ca9ec1fc3a7469f8c8a80bcb32d
# ./data//2017/95f590cafaf00309459c3d6dcfa757ea
# ./data//2017/225314df1f4d3f360598f517b1e72a6e
# ./data//2017/dcc20712600bb59daf4211f752b9daf9
# ./data//2017/b244fdb7d0050da694cf3c29ac426884
# ./data//2017/ecc60725f129737973a6f8571eb244c8
# Year: 2017 - week: 4
# Requested week slot: 01/22/2017 - 01/29/2017
# Ended downloading
# Image empty:  0
# This image is being replaced..
# This image is being replaced..
# Slot corrected to:  [(datetime.date(2017, 1, 22), datetime.date(2017, 1, 31))]
# image_2017-01-22
# ./data/2017/4f935aa9bdf0f9c8fa2cbc8214149d77/response.tiff renamed to ./data/2017/4f935aa9bdf0f9c8fa2cbc8214149d77/image_2017-01-22.tiff
# ./data//2017/21a57fbf82b300e9c307d60d2400f912
# ./data//2017/cf48fe4e224dcd182035985ff33f15a6
# Year: 2017 - week: 5
# Requested week slot: 01/29/2017 - 02/05/2017
# Ended downloading
# image_2017-01-29
# ./data/2017/fda855d80e5b1ca111818ec9a836ea0b/response.tiff renamed to ./data/2017/fda855d80e5b1ca111818ec9a836ea0b/image_2017-01-29.tiff
# Year: 2017 - week: 6
# Requested week slot: 02/05/2017 - 02/12/2017
# Ended downloading
# image_2017-02-05
# ./data/2017/05364c95d00e9dc9992226746a85e9ee/response.tiff renamed to ./data/2017/05364c95d00e9dc9992226746a85e9ee/image_2017-02-05.tiff
# Year: 2017 - week: 7
# Requested week slot: 02/12/2017 - 02/19/2017
# Ended downloading
# image_2017-02-12
# ./data/2017/1e2be49098cf3b9ffc86c71f1ac128e6/response.tiff renamed to ./data/2017/1e2be49098cf3b9ffc86c71f1ac128e6/image_2017-02-12.tiff
# Year: 2017 - week: 8
# Requested week slot: 02/19/2017 - 02/26/2017
# Ended downloading
# image_2017-02-19
# ./data/2017/503801e71ad6bbc8fb7f0b63b2806f7e/response.tiff renamed to ./data/2017/503801e71ad6bbc8fb7f0b63b2806f7e/image_2017-02-19.tiff
# Year: 2017 - week: 9
# Requested week slot: 02/26/2017 - 03/05/2017
# Ended downloading
# image_2017-02-26
# ./data/2017/7d025f0e8ca883ae12cc816dba18bd52/response.tiff renamed to ./data/2017/7d025f0e8ca883ae12cc816dba18bd52/image_2017-02-26.tiff
# Year: 2017 - week: 10
# Requested week slot: 03/05/2017 - 03/12/2017
# Ended downloading
# image_2017-03-05
# ./data/2017/a2b2068f1e62be73a98e0f0dc10a29da/response.tiff renamed to ./data/2017/a2b2068f1e62be73a98e0f0dc10a29da/image_2017-03-05.tiff
# Year: 2017 - week: 11
# Requested week slot: 03/12/2017 - 03/19/2017
# Ended downloading
# image_2017-03-12
# ./data/2017/870952aaa8c12228143e8017fb684d94/response.tiff renamed to ./data/2017/870952aaa8c12228143e8017fb684d94/image_2017-03-12.tiff
# Year: 2017 - week: 12
# Requested week slot: 03/19/2017 - 03/26/2017
# Ended downloading
# image_2017-03-19
# ./data/2017/9ee8c53eedbbfa0117fe8930c82ed801/response.tiff renamed to ./data/2017/9ee8c53eedbbfa0117fe8930c82ed801/image_2017-03-19.tiff
# Year: 2017 - week: 13
# Requested week slot: 03/26/2017 - 04/02/2017
# Ended downloading
# image_2017-03-26
# ./data/2017/e923b6a20368f0d6a601ad90458abba4/response.tiff renamed to ./data/2017/e923b6a20368f0d6a601ad90458abba4/image_2017-03-26.tiff
# Year: 2017 - week: 14
# Requested week slot: 04/02/2017 - 04/09/2017
# Ended downloading
# image_2017-04-02
# ./data/2017/f8c9b7492e5c010563baed03b863dd4a/response.tiff renamed to ./data/2017/f8c9b7492e5c010563baed03b863dd4a/image_2017-04-02.tiff
# Year: 2017 - week: 15
# Requested week slot: 04/09/2017 - 04/16/2017
# Ended downloading
# image_2017-04-09
# ./data/2017/a188876dcc779ddb993dc2d396d8c586/response.tiff renamed to ./data/2017/a188876dcc779ddb993dc2d396d8c586/image_2017-04-09.tiff
# Year: 2017 - week: 16
# Requested week slot: 04/16/2017 - 04/23/2017
# Ended downloading
# Image empty:  0
# This image is being replaced..
# Slot corrected to:  [(datetime.date(2017, 4, 16), datetime.date(2017, 4, 24))]
# image_2017-04-16
# ./data/2017/72caf2bb767063e276e3c8ae0cb68778/response.tiff renamed to ./data/2017/72caf2bb767063e276e3c8ae0cb68778/image_2017-04-16.tiff
# ./data//2017/30b9e5b9aa991260c364d63043ee28be
# Year: 2017 - week: 17
# Requested week slot: 04/23/2017 - 04/30/2017
# Ended downloading
# image_2017-04-23
# ./data/2017/92c5a6047ea8d6a52d64f68655100cde/response.tiff renamed to ./data/2017/92c5a6047ea8d6a52d64f68655100cde/image_2017-04-23.tiff
# Year: 2017 - week: 18
# Requested week slot: 04/30/2017 - 05/07/2017
# Ended downloading
# image_2017-04-30
# ./data/2017/4e977021ba05a4b344dcb0f3207f3af0/response.tiff renamed to ./data/2017/4e977021ba05a4b344dcb0f3207f3af0/image_2017-04-30.tiff
# Year: 2017 - week: 19
# Requested week slot: 05/07/2017 - 05/14/2017
# Ended downloading
# image_2017-05-07
# ./data/2017/e92e556a3c07cae015767ff2c2adb265/response.tiff renamed to ./data/2017/e92e556a3c07cae015767ff2c2adb265/image_2017-05-07.tiff
# Year: 2017 - week: 20
# Requested week slot: 05/14/2017 - 05/21/2017
# Ended downloading
# image_2017-05-14
# ./data/2017/2bb2ec4a237115018aba690663b86473/response.tiff renamed to ./data/2017/2bb2ec4a237115018aba690663b86473/image_2017-05-14.tiff
# Year: 2017 - week: 21
# Requested week slot: 05/21/2017 - 05/28/2017
# Ended downloading
# image_2017-05-21
# ./data/2017/aa9cf39d35209c8076ff3d034f4f836b/response.tiff renamed to ./data/2017/aa9cf39d35209c8076ff3d034f4f836b/image_2017-05-21.tiff
# Year: 2017 - week: 22
# Requested week slot: 05/28/2017 - 06/04/2017
# Ended downloading
# image_2017-05-28
# ./data/2017/a735f0260ce851cc6826fd79bba33e1d/response.tiff renamed to ./data/2017/a735f0260ce851cc6826fd79bba33e1d/image_2017-05-28.tiff
# Year: 2017 - week: 23
# Requested week slot: 06/04/2017 - 06/11/2017
# Ended downloading
# image_2017-06-04
# ./data/2017/9af3282771b80d975b50337ce39227a9/response.tiff renamed to ./data/2017/9af3282771b80d975b50337ce39227a9/image_2017-06-04.tiff
# Year: 2017 - week: 24
# Requested week slot: 06/11/2017 - 06/18/2017
# Ended downloading
# image_2017-06-11
# ./data/2017/95285eba4e508869fcabc82a636f40d9/response.tiff renamed to ./data/2017/95285eba4e508869fcabc82a636f40d9/image_2017-06-11.tiff
# Year: 2017 - week: 25
# Requested week slot: 06/18/2017 - 06/25/2017
# Ended downloading
# image_2017-06-18
# ./data/2017/16dcf74dfea7a6433e0056f8148e4a3c/response.tiff renamed to ./data/2017/16dcf74dfea7a6433e0056f8148e4a3c/image_2017-06-18.tiff
# Year: 2017 - week: 26
# Requested week slot: 06/25/2017 - 07/02/2017
# Ended downloading
# image_2017-06-25
# ./data/2017/23bc39c78d2619e53e1c8504630eb87d/response.tiff renamed to ./data/2017/23bc39c78d2619e53e1c8504630eb87d/image_2017-06-25.tiff
# Year: 2017 - week: 27
# Requested week slot: 07/02/2017 - 07/09/2017
# Ended downloading
# image_2017-07-02
# ./data/2017/6f7ff0c0aa5645cdae5221ee77db0dd2/response.tiff renamed to ./data/2017/6f7ff0c0aa5645cdae5221ee77db0dd2/image_2017-07-02.tiff
# Year: 2017 - week: 28
# Requested week slot: 07/09/2017 - 07/16/2017
# Ended downloading
# image_2017-07-09
# ./data/2017/33f3d866a3a7b37d0abcb2b996001af4/response.tiff renamed to ./data/2017/33f3d866a3a7b37d0abcb2b996001af4/image_2017-07-09.tiff
# Year: 2017 - week: 29
# Requested week slot: 07/16/2017 - 07/23/2017
# Ended downloading
# image_2017-07-16
# ./data/2017/4e390a460a6d2bde6b77b2425c50a85a/response.tiff renamed to ./data/2017/4e390a460a6d2bde6b77b2425c50a85a/image_2017-07-16.tiff
# Year: 2017 - week: 30
# Requested week slot: 07/23/2017 - 07/30/2017
# Ended downloading
# image_2017-07-23
# ./data/2017/28c5879fb4b739fcc4a5327d43ee1863/response.tiff renamed to ./data/2017/28c5879fb4b739fcc4a5327d43ee1863/image_2017-07-23.tiff
# Year: 2017 - week: 31
# Requested week slot: 07/30/2017 - 08/06/2017
# Ended downloading
# image_2017-07-30
# ./data/2017/185ed9df1174cfbeca5d5c78301e2c86/response.tiff renamed to ./data/2017/185ed9df1174cfbeca5d5c78301e2c86/image_2017-07-30.tiff
# Year: 2017 - week: 32
# Requested week slot: 08/06/2017 - 08/13/2017
# Ended downloading
# image_2017-08-06
# ./data/2017/9ded71eb71d45eb7ab2c0e3af851ca76/response.tiff renamed to ./data/2017/9ded71eb71d45eb7ab2c0e3af851ca76/image_2017-08-06.tiff
# Year: 2017 - week: 33
# Requested week slot: 08/13/2017 - 08/20/2017
# Ended downloading
# image_2017-08-13
# ./data/2017/63d3f196aacfa882a39a1126a19b2f78/response.tiff renamed to ./data/2017/63d3f196aacfa882a39a1126a19b2f78/image_2017-08-13.tiff
# Year: 2017 - week: 34
# Requested week slot: 08/20/2017 - 08/27/2017
# Ended downloading
# image_2017-08-20
# ./data/2017/a099911b409ec4374c281a925aa71a2b/response.tiff renamed to ./data/2017/a099911b409ec4374c281a925aa71a2b/image_2017-08-20.tiff
# Year: 2017 - week: 35
# Requested week slot: 08/27/2017 - 09/03/2017
# Ended downloading
# image_2017-08-27
# ./data/2017/d0eef2e55ec55abc5676a71762ecf2a3/response.tiff renamed to ./data/2017/d0eef2e55ec55abc5676a71762ecf2a3/image_2017-08-27.tiff
# Year: 2017 - week: 36
# Requested week slot: 09/03/2017 - 09/10/2017
# Ended downloading
# image_2017-09-03
# ./data/2017/a8daae57b8ea351bfc69e40f14f39037/response.tiff renamed to ./data/2017/a8daae57b8ea351bfc69e40f14f39037/image_2017-09-03.tiff
# Year: 2017 - week: 37
# Requested week slot: 09/10/2017 - 09/17/2017
# Ended downloading
# image_2017-09-10
# ./data/2017/3d6a62b8be9c63a0da4936d84a905173/response.tiff renamed to ./data/2017/3d6a62b8be9c63a0da4936d84a905173/image_2017-09-10.tiff
# Year: 2017 - week: 38
# Requested week slot: 09/17/2017 - 09/24/2017
# Ended downloading
# image_2017-09-17
# ./data/2017/1e6b2fe7534c5f12fff551af392b0fee/response.tiff renamed to ./data/2017/1e6b2fe7534c5f12fff551af392b0fee/image_2017-09-17.tiff
# Year: 2017 - week: 39
# Requested week slot: 09/24/2017 - 10/01/2017
# Ended downloading
# image_2017-09-24
# ./data/2017/3e0cd82f526831eaf8d46ae7ff2730e3/response.tiff renamed to ./data/2017/3e0cd82f526831eaf8d46ae7ff2730e3/image_2017-09-24.tiff
# Year: 2017 - week: 40
# Requested week slot: 10/01/2017 - 10/08/2017
# Ended downloading
# image_2017-10-01
# ./data/2017/06537b6c23f9bb2201e3fe4596809105/response.tiff renamed to ./data/2017/06537b6c23f9bb2201e3fe4596809105/image_2017-10-01.tiff
# Year: 2017 - week: 41
# Requested week slot: 10/08/2017 - 10/15/2017
# Ended downloading
# image_2017-10-08
# ./data/2017/45abddcd3da1306b2807c755ae18e2d3/response.tiff renamed to ./data/2017/45abddcd3da1306b2807c755ae18e2d3/image_2017-10-08.tiff
# Year: 2017 - week: 42
# Requested week slot: 10/15/2017 - 10/22/2017
# Ended downloading
# image_2017-10-15
# ./data/2017/a3168b8defa8347e52d320a513b82221/response.tiff renamed to ./data/2017/a3168b8defa8347e52d320a513b82221/image_2017-10-15.tiff
# Year: 2017 - week: 43
# Requested week slot: 10/22/2017 - 10/29/2017
# Ended downloading
# image_2017-10-22
# ./data/2017/cb35c0b8fdaf3b9b3b72dc9a408269f4/response.tiff renamed to ./data/2017/cb35c0b8fdaf3b9b3b72dc9a408269f4/image_2017-10-22.tiff
# Year: 2017 - week: 44
# Requested week slot: 10/29/2017 - 11/05/2017
# Ended downloading
# image_2017-10-29
# ./data/2017/75ef2fedc266c6922ee981e8457a4ade/response.tiff renamed to ./data/2017/75ef2fedc266c6922ee981e8457a4ade/image_2017-10-29.tiff
# Year: 2017 - week: 45
# Requested week slot: 11/05/2017 - 11/12/2017
# Ended downloading
# image_2017-11-05
# ./data/2017/7694e4ad0c00cd2774a891d16ca156db/response.tiff renamed to ./data/2017/7694e4ad0c00cd2774a891d16ca156db/image_2017-11-05.tiff
# Year: 2017 - week: 46
# Requested week slot: 11/12/2017 - 11/19/2017
# Ended downloading
# image_2017-11-12
# ./data/2017/83e824821aa1164d746c853d3a4e8c2b/response.tiff renamed to ./data/2017/83e824821aa1164d746c853d3a4e8c2b/image_2017-11-12.tiff
# Year: 2017 - week: 47
# Requested week slot: 11/19/2017 - 11/26/2017
# Ended downloading
# image_2017-11-19
# ./data/2017/d0c71c5e0859001af424b3b5868d3117/response.tiff renamed to ./data/2017/d0c71c5e0859001af424b3b5868d3117/image_2017-11-19.tiff
# Year: 2017 - week: 48
# Requested week slot: 11/26/2017 - 12/03/2017
# Ended downloading
# image_2017-11-26
# ./data/2017/90ed6a6219d82b7487453bbda3d916aa/response.tiff renamed to ./data/2017/90ed6a6219d82b7487453bbda3d916aa/image_2017-11-26.tiff
# Year: 2017 - week: 49
# Requested week slot: 12/03/2017 - 12/10/2017
# Ended downloading
# image_2017-12-03
# ./data/2017/6a5882e904f8fa0b068e52c6073ff681/response.tiff renamed to ./data/2017/6a5882e904f8fa0b068e52c6073ff681/image_2017-12-03.tiff
# Year: 2017 - week: 50
# Requested week slot: 12/10/2017 - 12/17/2017
# Ended downloading
# image_2017-12-10
# ./data/2017/5bf1b4e5a437f0d52a885ac176a3e01d/response.tiff renamed to ./data/2017/5bf1b4e5a437f0d52a885ac176a3e01d/image_2017-12-10.tiff
# Year: 2017 - week: 51
# Requested week slot: 12/17/2017 - 12/24/2017
# Ended downloading
# image_2017-12-17
# ./data/2017/ccc4e56f3f5ef67be8427adf9d76a914/response.tiff renamed to ./data/2017/ccc4e56f3f5ef67be8427adf9d76a914/image_2017-12-17.tiff
# Year: 2017 - week: 52
# Requested week slot: 12/24/2017 - 12/31/2017
# Ended downloading
# image_2017-12-24
# ./data/2017/e7b270ef9b9658b71a6ec8f6d85ec5ec/response.tiff renamed to ./data/2017/e7b270ef9b9658b71a6ec8f6d85ec5ec/image_2017-12-24.tiff
# Year: 2018 - week: 1
# Requested week slot: 12/31/2017 - 01/07/2018
# Ended downloading
# image_2017-12-31
# ./data/2018/6c50bee5704f234c4c42d72f179f7498/response.tiff renamed to ./data/2018/6c50bee5704f234c4c42d72f179f7498/image_2017-12-31.tiff
# Year: 2018 - week: 2
# Requested week slot: 01/07/2018 - 01/14/2018
# Ended downloading
# image_2018-01-07
# ./data/2018/39fd259d495142205e70dc45bb196697/response.tiff renamed to ./data/2018/39fd259d495142205e70dc45bb196697/image_2018-01-07.tiff
# Year: 2018 - week: 3
# Requested week slot: 01/14/2018 - 01/21/2018
# Ended downloading
# image_2018-01-14
# ./data/2018/3844b9f7d52044a799d6c743aa314e4f/response.tiff renamed to ./data/2018/3844b9f7d52044a799d6c743aa314e4f/image_2018-01-14.tiff
# Year: 2018 - week: 4
# Requested week slot: 01/21/2018 - 01/28/2018
# Ended downloading
# image_2018-01-21
# ./data/2018/0a5de7dbb4a6f6563d5098957fd7577e/response.tiff renamed to ./data/2018/0a5de7dbb4a6f6563d5098957fd7577e/image_2018-01-21.tiff
# Year: 2018 - week: 5
# Requested week slot: 01/28/2018 - 02/04/2018
# Ended downloading
# image_2018-01-28
# ./data/2018/576c492fec6b567adb83656e94a8ee6f/response.tiff renamed to ./data/2018/576c492fec6b567adb83656e94a8ee6f/image_2018-01-28.tiff
# Year: 2018 - week: 6
# Requested week slot: 02/04/2018 - 02/11/2018
# Ended downloading
# image_2018-02-04
# ./data/2018/f97bf955a80178c5ec92b94ebdbeedd4/response.tiff renamed to ./data/2018/f97bf955a80178c5ec92b94ebdbeedd4/image_2018-02-04.tiff
# Year: 2018 - week: 7
# Requested week slot: 02/11/2018 - 02/18/2018
# Ended downloading
# image_2018-02-11
# ./data/2018/82dbc39751df625575070dd7e650550b/response.tiff renamed to ./data/2018/82dbc39751df625575070dd7e650550b/image_2018-02-11.tiff
# Year: 2018 - week: 8
# Requested week slot: 02/18/2018 - 02/25/2018
# Ended downloading
# image_2018-02-18
# ./data/2018/c6a84d63a62fb9e8c65bfc8fba042701/response.tiff renamed to ./data/2018/c6a84d63a62fb9e8c65bfc8fba042701/image_2018-02-18.tiff
# Year: 2018 - week: 9
# Requested week slot: 02/25/2018 - 03/04/2018
# Ended downloading
# image_2018-02-25
# ./data/2018/5b116e235adf326c4f1ddc64f2b89a9e/response.tiff renamed to ./data/2018/5b116e235adf326c4f1ddc64f2b89a9e/image_2018-02-25.tiff
# Year: 2018 - week: 10
# Requested week slot: 03/04/2018 - 03/11/2018
# Ended downloading
# image_2018-03-04
# ./data/2018/e426997a82356ed01714defbd6b606c2/response.tiff renamed to ./data/2018/e426997a82356ed01714defbd6b606c2/image_2018-03-04.tiff
# Year: 2018 - week: 11
# Requested week slot: 03/11/2018 - 03/18/2018
# Ended downloading
# image_2018-03-11
# ./data/2018/d84ac4bf6d48fb1edbfbd651d419b5ac/response.tiff renamed to ./data/2018/d84ac4bf6d48fb1edbfbd651d419b5ac/image_2018-03-11.tiff
# Year: 2018 - week: 12
# Requested week slot: 03/18/2018 - 03/25/2018
# Ended downloading
# image_2018-03-18
# ./data/2018/7c4c4bfb99d4facf42819bde076d3b96/response.tiff renamed to ./data/2018/7c4c4bfb99d4facf42819bde076d3b96/image_2018-03-18.tiff
# Year: 2018 - week: 13
# Requested week slot: 03/25/2018 - 04/01/2018
# Ended downloading
# image_2018-03-25
# ./data/2018/71b734bab85f4a0fe7a748628476955b/response.tiff renamed to ./data/2018/71b734bab85f4a0fe7a748628476955b/image_2018-03-25.tiff
# Year: 2018 - week: 14
# Requested week slot: 04/01/2018 - 04/08/2018
# Ended downloading
# image_2018-04-01
# ./data/2018/fe05053f8d1ab617a4f99ff3c9e2f4da/response.tiff renamed to ./data/2018/fe05053f8d1ab617a4f99ff3c9e2f4da/image_2018-04-01.tiff
# Year: 2018 - week: 15
# Requested week slot: 04/08/2018 - 04/15/2018
# Ended downloading
# image_2018-04-08
# ./data/2018/fc1c946eb7457d9641c60a01e564198d/response.tiff renamed to ./data/2018/fc1c946eb7457d9641c60a01e564198d/image_2018-04-08.tiff
# Year: 2018 - week: 16
# Requested week slot: 04/15/2018 - 04/22/2018
# Ended downloading
# image_2018-04-15
# ./data/2018/458e0e2e99fa8babb2093932f95feb58/response.tiff renamed to ./data/2018/458e0e2e99fa8babb2093932f95feb58/image_2018-04-15.tiff
# Year: 2018 - week: 17
# Requested week slot: 04/22/2018 - 04/29/2018
# Ended downloading
# image_2018-04-22
# ./data/2018/1b870814702621d582963f8f8bd08299/response.tiff renamed to ./data/2018/1b870814702621d582963f8f8bd08299/image_2018-04-22.tiff
# Year: 2018 - week: 18
# Requested week slot: 04/29/2018 - 05/06/2018
# Ended downloading
# image_2018-04-29
# ./data/2018/021cf8fa939f1dbc970789537dccabe4/response.tiff renamed to ./data/2018/021cf8fa939f1dbc970789537dccabe4/image_2018-04-29.tiff
# Year: 2018 - week: 19
# Requested week slot: 05/06/2018 - 05/13/2018
# Ended downloading
# image_2018-05-06
# ./data/2018/49b40be16c1c82d1a4812b4ebdfeaf4f/response.tiff renamed to ./data/2018/49b40be16c1c82d1a4812b4ebdfeaf4f/image_2018-05-06.tiff
# Year: 2018 - week: 20
# Requested week slot: 05/13/2018 - 05/20/2018
# Ended downloading
# image_2018-05-13
# ./data/2018/9f810b7e995600307601c0c1d83a2c34/response.tiff renamed to ./data/2018/9f810b7e995600307601c0c1d83a2c34/image_2018-05-13.tiff
# Year: 2018 - week: 21
# Requested week slot: 05/20/2018 - 05/27/2018
# Ended downloading
# image_2018-05-20
# ./data/2018/7b7cb1e32b8cc6024b083398dbfce223/response.tiff renamed to ./data/2018/7b7cb1e32b8cc6024b083398dbfce223/image_2018-05-20.tiff
# Year: 2018 - week: 22
# Requested week slot: 05/27/2018 - 06/03/2018
# Ended downloading
# image_2018-05-27
# ./data/2018/de29b060367d623c0a011e9088a79fdb/response.tiff renamed to ./data/2018/de29b060367d623c0a011e9088a79fdb/image_2018-05-27.tiff
# Year: 2018 - week: 23
# Requested week slot: 06/03/2018 - 06/10/2018
# Ended downloading
# image_2018-06-03
# ./data/2018/f496eb270a80af1e6551d041b284419e/response.tiff renamed to ./data/2018/f496eb270a80af1e6551d041b284419e/image_2018-06-03.tiff
# Year: 2018 - week: 24
# Requested week slot: 06/10/2018 - 06/17/2018
# Ended downloading
# image_2018-06-10
# ./data/2018/5c147dad0abbc397137ea9f6230bd1c2/response.tiff renamed to ./data/2018/5c147dad0abbc397137ea9f6230bd1c2/image_2018-06-10.tiff
# Year: 2018 - week: 25
# Requested week slot: 06/17/2018 - 06/24/2018
# Ended downloading
# image_2018-06-17
# ./data/2018/7b547cdd6c6112660c74db5aa5864e4e/response.tiff renamed to ./data/2018/7b547cdd6c6112660c74db5aa5864e4e/image_2018-06-17.tiff
# Year: 2018 - week: 26
# Requested week slot: 06/24/2018 - 07/01/2018
# Ended downloading
# image_2018-06-24
# ./data/2018/4c5ca92585b7104c5b5585b75f874893/response.tiff renamed to ./data/2018/4c5ca92585b7104c5b5585b75f874893/image_2018-06-24.tiff
# Year: 2018 - week: 27
# ...
# image_2017-09-17
# ./data/2017/6081553f9e1d5e1c1b247a7781d38c75/response.tiff renamed to ./data/2017/6081553f9e1d5e1c1b247a7781d38c75/image_2017-09-17.tiff
# Year: 2017 - week: 39
# Requested week slot: 09/24/2017 - 10/01/2017
# Ended downloading
# image_2017-09-24
# ./data/2017/6e8c0e0a62fe0ce365ef1ccf2998c4f1/response.tiff renamed to ./data/2017/6e8c0e0a62fe0ce365ef1ccf2998c4f1/image_2017-09-24.tiff
# Year: 2017 - week: 40
# Requested week slot: 10/01/2017 - 10/08/2017
# Ended downloading
# image_2017-10-01
# ./data/2017/c8a9caf0eafcc7386bb3eef504676806/response.tiff renamed to ./data/2017/c8a9caf0eafcc7386bb3eef504676806/image_2017-10-01.tiff
# Year: 2017 - week: 41
# Requested week slot: 10/08/2017 - 10/15/2017
# Ended downloading
# image_2017-10-08
# ./data/2017/3dbd2678ebe5dc8de975e08cec1e2c08/response.tiff renamed to ./data/2017/3dbd2678ebe5dc8de975e08cec1e2c08/image_2017-10-08.tiff
# Year: 2017 - week: 42
# Requested week slot: 10/15/2017 - 10/22/2017
# Ended downloading
# image_2017-10-15
# ./data/2017/dec27978a3a16b0c27a81bdc71184fca/response.tiff renamed to ./data/2017/dec27978a3a16b0c27a81bdc71184fca/image_2017-10-15.tiff
# Year: 2017 - week: 43
# Requested week slot: 10/22/2017 - 10/29/2017
# Ended downloading
# image_2017-10-22
# ./data/2017/fbd85129bf16453ff877ed8f782a858a/response.tiff renamed to ./data/2017/fbd85129bf16453ff877ed8f782a858a/image_2017-10-22.tiff
# Year: 2017 - week: 44
# Requested week slot: 10/29/2017 - 11/05/2017
# Ended downloading
# image_2017-10-29
# ./data/2017/34c21626277a14efc0bf7be070d957e7/response.tiff renamed to ./data/2017/34c21626277a14efc0bf7be070d957e7/image_2017-10-29.tiff
# Year: 2017 - week: 45
# Requested week slot: 11/05/2017 - 11/12/2017
# Ended downloading
# image_2017-11-05
# ./data/2017/58632307472adf6f432a9b9e088444fa/response.tiff renamed to ./data/2017/58632307472adf6f432a9b9e088444fa/image_2017-11-05.tiff
# Year: 2017 - week: 46
# Requested week slot: 11/12/2017 - 11/19/2017
# Ended downloading
# image_2017-11-12
# ./data/2017/c44c2e600a0e2437c39f8b3b09f77605/response.tiff renamed to ./data/2017/c44c2e600a0e2437c39f8b3b09f77605/image_2017-11-12.tiff
# Year: 2017 - week: 47
# Requested week slot: 11/19/2017 - 11/26/2017
# Ended downloading
# image_2017-11-19
# ./data/2017/bb51e3e7fac90393433194d5a1081ec5/response.tiff renamed to ./data/2017/bb51e3e7fac90393433194d5a1081ec5/image_2017-11-19.tiff
# Year: 2017 - week: 48
# Requested week slot: 11/26/2017 - 12/03/2017
# Ended downloading
# image_2017-11-26
# ./data/2017/fb3a091e4c7660840d6910c9f2a8e5d8/response.tiff renamed to ./data/2017/fb3a091e4c7660840d6910c9f2a8e5d8/image_2017-11-26.tiff
# Year: 2017 - week: 49
# Requested week slot: 12/03/2017 - 12/10/2017
# Ended downloading
# image_2017-12-03
# ./data/2017/fd7a8cc6498077fbcd8c85232e1e6f26/response.tiff renamed to ./data/2017/fd7a8cc6498077fbcd8c85232e1e6f26/image_2017-12-03.tiff
# Year: 2017 - week: 50
# Requested week slot: 12/10/2017 - 12/17/2017
# Ended downloading
# image_2017-12-10
# ./data/2017/47e17e1d1c9db903a7f9db42a95cf3d7/response.tiff renamed to ./data/2017/47e17e1d1c9db903a7f9db42a95cf3d7/image_2017-12-10.tiff
# Year: 2017 - week: 51
# Requested week slot: 12/17/2017 - 12/24/2017
# Ended downloading
# image_2017-12-17
# ./data/2017/76606b061331f0cd47a027144845e2c2/response.tiff renamed to ./data/2017/76606b061331f0cd47a027144845e2c2/image_2017-12-17.tiff
# Year: 2017 - week: 52
# Requested week slot: 12/24/2017 - 12/31/2017
# Ended downloading
# image_2017-12-24
# ./data/2017/7fb184795f0ea7ecbaffd6b7656cd0ab/response.tiff renamed to ./data/2017/7fb184795f0ea7ecbaffd6b7656cd0ab/image_2017-12-24.tiff
# Year: 2018 - week: 1
# Requested week slot: 12/31/2017 - 01/07/2018
# Ended downloading
# image_2017-12-31
# ./data/2018/597b525edb2363c4c7ff6b95267e2d4d/response.tiff renamed to ./data/2018/597b525edb2363c4c7ff6b95267e2d4d/image_2017-12-31.tiff
# Year: 2018 - week: 2
# Requested week slot: 01/07/2018 - 01/14/2018
# Ended downloading
# image_2018-01-07
# ./data/2018/372e49f2f4efc89dca14bf60858f9d41/response.tiff renamed to ./data/2018/372e49f2f4efc89dca14bf60858f9d41/image_2018-01-07.tiff
# Year: 2018 - week: 3
# Requested week slot: 01/14/2018 - 01/21/2018
# Ended downloading
# image_2018-01-14
# ./data/2018/b4a4e79f4512f4ba9af7f816bba5da5e/response.tiff renamed to ./data/2018/b4a4e79f4512f4ba9af7f816bba5da5e/image_2018-01-14.tiff
# Year: 2018 - week: 4
# Requested week slot: 01/21/2018 - 01/28/2018
# Ended downloading
# image_2018-01-21
# ./data/2018/79adac6e094f33bd0817e46c8131abdf/response.tiff renamed to ./data/2018/79adac6e094f33bd0817e46c8131abdf/image_2018-01-21.tiff
# Year: 2018 - week: 5
# Requested week slot: 01/28/2018 - 02/04/2018
# Ended downloading
# image_2018-01-28
# ./data/2018/b0599be5f40d87dc745dfba2ab761c67/response.tiff renamed to ./data/2018/b0599be5f40d87dc745dfba2ab761c67/image_2018-01-28.tiff
# Year: 2018 - week: 6
# Requested week slot: 02/04/2018 - 02/11/2018
# Ended downloading
# image_2018-02-04
# ./data/2018/d0811872e4c39574ff3b5a27933c7417/response.tiff renamed to ./data/2018/d0811872e4c39574ff3b5a27933c7417/image_2018-02-04.tiff
# Year: 2018 - week: 7
# Requested week slot: 02/11/2018 - 02/18/2018
# Ended downloading
# image_2018-02-11
# ./data/2018/628f471e8a4a79d71f65e2f513e9f572/response.tiff renamed to ./data/2018/628f471e8a4a79d71f65e2f513e9f572/image_2018-02-11.tiff
# Year: 2018 - week: 8
# Requested week slot: 02/18/2018 - 02/25/2018
# Ended downloading
# image_2018-02-18
# ./data/2018/c434124c98c409a42129330f0d81d69c/response.tiff renamed to ./data/2018/c434124c98c409a42129330f0d81d69c/image_2018-02-18.tiff
# Year: 2018 - week: 9
# Requested week slot: 02/25/2018 - 03/04/2018
# Ended downloading
# image_2018-02-25
# ./data/2018/a36cba7443655e67e59971a5dfe40318/response.tiff renamed to ./data/2018/a36cba7443655e67e59971a5dfe40318/image_2018-02-25.tiff
# Year: 2018 - week: 10
# Requested week slot: 03/04/2018 - 03/11/2018
# Ended downloading
# image_2018-03-04
# ./data/2018/e3f77f46ce8c0cfc4ff21e8b9a718f14/response.tiff renamed to ./data/2018/e3f77f46ce8c0cfc4ff21e8b9a718f14/image_2018-03-04.tiff
# Year: 2018 - week: 11
# Requested week slot: 03/11/2018 - 03/18/2018
# Ended downloading
# image_2018-03-11
# ./data/2018/0c9971a5454daa53880ced4603a6fa79/response.tiff renamed to ./data/2018/0c9971a5454daa53880ced4603a6fa79/image_2018-03-11.tiff
# Year: 2018 - week: 12
# Requested week slot: 03/18/2018 - 03/25/2018
# Ended downloading
# image_2018-03-18
# ./data/2018/4be984d9bd1abcc1c3e9d8676a9af387/response.tiff renamed to ./data/2018/4be984d9bd1abcc1c3e9d8676a9af387/image_2018-03-18.tiff
# Year: 2018 - week: 13
# Requested week slot: 03/25/2018 - 04/01/2018
# Ended downloading
# image_2018-03-25
# ./data/2018/8f462c82af16aa06c560ea8d4d99a624/response.tiff renamed to ./data/2018/8f462c82af16aa06c560ea8d4d99a624/image_2018-03-25.tiff
# Year: 2018 - week: 14
# Requested week slot: 04/01/2018 - 04/08/2018
# Ended downloading
# image_2018-04-01
# ./data/2018/4a75407a44b42cf6ccb5305bb53c18c6/response.tiff renamed to ./data/2018/4a75407a44b42cf6ccb5305bb53c18c6/image_2018-04-01.tiff
# Year: 2018 - week: 15
# Requested week slot: 04/08/2018 - 04/15/2018
# Ended downloading
# image_2018-04-08
# ./data/2018/0b285e505c3b905c98db04a04e1a82cf/response.tiff renamed to ./data/2018/0b285e505c3b905c98db04a04e1a82cf/image_2018-04-08.tiff
# Year: 2018 - week: 16
# Requested week slot: 04/15/2018 - 04/22/2018
# Ended downloading
# image_2018-04-15
# ./data/2018/bb9684725b3c6e4804f3e156751fba0f/response.tiff renamed to ./data/2018/bb9684725b3c6e4804f3e156751fba0f/image_2018-04-15.tiff
# Year: 2018 - week: 17
# Requested week slot: 04/22/2018 - 04/29/2018
# Ended downloading
# image_2018-04-22
# ./data/2018/3410eba21f451c91284dfb49cab12298/response.tiff renamed to ./data/2018/3410eba21f451c91284dfb49cab12298/image_2018-04-22.tiff
# Year: 2018 - week: 18
# Requested week slot: 04/29/2018 - 05/06/2018
# Ended downloading
# image_2018-04-29
# ./data/2018/a1b6fb875033f0ece801da2e8a145354/response.tiff renamed to ./data/2018/a1b6fb875033f0ece801da2e8a145354/image_2018-04-29.tiff
# Year: 2018 - week: 19
# Requested week slot: 05/06/2018 - 05/13/2018
# Ended downloading
# image_2018-05-06
# ./data/2018/92628c60787d1399e9f0444e7ec9e5e4/response.tiff renamed to ./data/2018/92628c60787d1399e9f0444e7ec9e5e4/image_2018-05-06.tiff
# Year: 2018 - week: 20
# Requested week slot: 05/13/2018 - 05/20/2018
# Ended downloading
# image_2018-05-13
# ./data/2018/0ea7bf098b9d9de31e02bb1b3a76e6a8/response.tiff renamed to ./data/2018/0ea7bf098b9d9de31e02bb1b3a76e6a8/image_2018-05-13.tiff
# Year: 2018 - week: 21
# Requested week slot: 05/20/2018 - 05/27/2018
# Ended downloading
# image_2018-05-20
# ./data/2018/9bc0794b9eafbb7e6706aeea09cab1ca/response.tiff renamed to ./data/2018/9bc0794b9eafbb7e6706aeea09cab1ca/image_2018-05-20.tiff
# Year: 2018 - week: 22
# Requested week slot: 05/27/2018 - 06/03/2018
# Ended downloading
# image_2018-05-27
# ./data/2018/cabdb00e561d52fc9928cf44d7f9b942/response.tiff renamed to ./data/2018/cabdb00e561d52fc9928cf44d7f9b942/image_2018-05-27.tiff
# Year: 2018 - week: 23
# Requested week slot: 06/03/2018 - 06/10/2018
# Ended downloading
# image_2018-06-03
# ./data/2018/5eff41ac5fa56802bb6dd48c8e8be885/response.tiff renamed to ./data/2018/5eff41ac5fa56802bb6dd48c8e8be885/image_2018-06-03.tiff
# Year: 2018 - week: 24
# Requested week slot: 06/10/2018 - 06/17/2018
# Ended downloading
# image_2018-06-10
# ./data/2018/259986e2a49a4f45c115278327c529fc/response.tiff renamed to ./data/2018/259986e2a49a4f45c115278327c529fc/image_2018-06-10.tiff
# Year: 2018 - week: 25
# Requested week slot: 06/17/2018 - 06/24/2018
# Ended downloading
# image_2018-06-17
# ./data/2018/63bf541b98bd0b1918645f26b880bc62/response.tiff renamed to ./data/2018/63bf541b98bd0b1918645f26b880bc62/image_2018-06-17.tiff
# Year: 2018 - week: 26
# Requested week slot: 06/24/2018 - 07/01/2018
# Ended downloading
# image_2018-06-24
# ./data/2018/b87919a296e211d544465322c3ba9294/response.tiff renamed to ./data/2018/b87919a296e211d544465322c3ba9294/image_2018-06-24.tiff
# Year: 2018 - week: 27
# Requested week slot: 07/01/2018 - 07/08/2018
# Ended downloading
# image_2018-07-01
# ./data/2018/e8ffdc8c5b1da8aeae0d24adf4da0a68/response.tiff renamed to ./data/2018/e8ffdc8c5b1da8aeae0d24adf4da0a68/image_2018-07-01.tiff
# Year: 2018 - week: 28
# Requested week slot: 07/08/2018 - 07/15/2018
# Ended downloading
# image_2018-07-08
# ./data/2018/83535cde35d6160be82bcce7d22e5d2a/response.tiff renamed to ./data/2018/83535cde35d6160be82bcce7d22e5d2a/image_2018-07-08.tiff
# Year: 2018 - week: 29
# Requested week slot: 07/15/2018 - 07/22/2018
# Ended downloading
# image_2018-07-15
# ./data/2018/556fd52f2ca294616c1337dc8ff60577/response.tiff renamed to ./data/2018/556fd52f2ca294616c1337dc8ff60577/image_2018-07-15.tiff
# Year: 2018 - week: 30
# Requested week slot: 07/22/2018 - 07/29/2018
# Ended downloading
# image_2018-07-22
# ./data/2018/aad79253b3f213843188582197cfa7fa/response.tiff renamed to ./data/2018/aad79253b3f213843188582197cfa7fa/image_2018-07-22.tiff
# Year: 2018 - week: 31
# Requested week slot: 07/29/2018 - 08/05/2018
# Ended downloading
# image_2018-07-29
# ./data/2018/2ec9022751b4eac5cb64b1c343c472da/response.tiff renamed to ./data/2018/2ec9022751b4eac5cb64b1c343c472da/image_2018-07-29.tiff
# Year: 2018 - week: 32
# Requested week slot: 08/05/2018 - 08/12/2018
# Ended downloading
# image_2018-08-05
# ./data/2018/e21eea0f2bb5b3c692b9d1f6fb1417f5/response.tiff renamed to ./data/2018/e21eea0f2bb5b3c692b9d1f6fb1417f5/image_2018-08-05.tiff
# Year: 2018 - week: 33
# Requested week slot: 08/12/2018 - 08/19/2018
# Ended downloading
# image_2018-08-12
# ./data/2018/4608fad7074eb83bf6df15e9abb37238/response.tiff renamed to ./data/2018/4608fad7074eb83bf6df15e9abb37238/image_2018-08-12.tiff
# Year: 2018 - week: 34
# Requested week slot: 08/19/2018 - 08/26/2018
# Ended downloading
# image_2018-08-19
# ./data/2018/ace6e62547888d7a1cfa9941882ac89f/response.tiff renamed to ./data/2018/ace6e62547888d7a1cfa9941882ac89f/image_2018-08-19.tiff
# Year: 2018 - week: 35
# Requested week slot: 08/26/2018 - 09/02/2018
# Ended downloading
# image_2018-08-26
# ./data/2018/88e25b187299fb1ca9b90722bd9ed236/response.tiff renamed to ./data/2018/88e25b187299fb1ca9b90722bd9ed236/image_2018-08-26.tiff
# Year: 2018 - week: 36
# Requested week slot: 09/02/2018 - 09/09/2018
# Ended downloading
# image_2018-09-02
# ./data/2018/82e0b9a498b431a343902795603d7d08/response.tiff renamed to ./data/2018/82e0b9a498b431a343902795603d7d08/image_2018-09-02.tiff
# Year: 2018 - week: 37
# Requested week slot: 09/09/2018 - 09/16/2018
# Ended downloading
# image_2018-09-09
# ./data/2018/21664d6b348001b95dfdf5fb5e39c4e3/response.tiff renamed to ./data/2018/21664d6b348001b95dfdf5fb5e39c4e3/image_2018-09-09.tiff
# Year: 2018 - week: 38
# Requested week slot: 09/16/2018 - 09/23/2018
# Ended downloading
# image_2018-09-16
# ./data/2018/bb455572a0084b97af96262dd2927529/response.tiff renamed to ./data/2018/bb455572a0084b97af96262dd2927529/image_2018-09-16.tiff
# Year: 2018 - week: 39
# Requested week slot: 09/23/2018 - 09/30/2018
# Ended downloading
# image_2018-09-23
# ./data/2018/fa333280fe2ee920f9f36bec1e918129/response.tiff renamed to ./data/2018/fa333280fe2ee920f9f36bec1e918129/image_2018-09-23.tiff
# Year: 2018 - week: 40
# Requested week slot: 09/30/2018 - 10/07/2018
# Ended downloading
# image_2018-09-30
# ./data/2018/e8b1f69e0f5d5f906ccd6169ed27efe7/response.tiff renamed to ./data/2018/e8b1f69e0f5d5f906ccd6169ed27efe7/image_2018-09-30.tiff
# Year: 2018 - week: 41
# Requested week slot: 10/07/2018 - 10/14/2018
# Ended downloading
# image_2018-10-07
# ./data/2018/a92c7ef3c11fde1fa8b2db9acfa53d82/response.tiff renamed to ./data/2018/a92c7ef3c11fde1fa8b2db9acfa53d82/image_2018-10-07.tiff
# Year: 2018 - week: 42
# Requested week slot: 10/14/2018 - 10/21/2018
# Ended downloading
# image_2018-10-14
# ./data/2018/1e96aca572a4fcd6e9e396fa62f6427b/response.tiff renamed to ./data/2018/1e96aca572a4fcd6e9e396fa62f6427b/image_2018-10-14.tiff
# Year: 2018 - week: 43
# Requested week slot: 10/21/2018 - 10/28/2018
# Ended downloading
# image_2018-10-21
# ./data/2018/b79481645c64a8bab059dd8b5d2375f9/response.tiff renamed to ./data/2018/b79481645c64a8bab059dd8b5d2375f9/image_2018-10-21.tiff
# Year: 2018 - week: 44
# Requested week slot: 10/28/2018 - 11/04/2018
# Ended downloading
# image_2018-10-28
# ./data/2018/52f041bd9070b038339a5e5ebf1c244d/response.tiff renamed to ./data/2018/52f041bd9070b038339a5e5ebf1c244d/image_2018-10-28.tiff
# Year: 2018 - week: 45
# Requested week slot: 11/04/2018 - 11/11/2018
# Ended downloading
# image_2018-11-04
# ./data/2018/321a7b781fae85a040f8eadfcc955ffb/response.tiff renamed to ./data/2018/321a7b781fae85a040f8eadfcc955ffb/image_2018-11-04.tiff
# Year: 2018 - week: 46
# Requested week slot: 11/11/2018 - 11/18/2018
# Ended downloading
# image_2018-11-11
# ./data/2018/517e8e6b090a637948c14358f02bcc28/response.tiff renamed to ./data/2018/517e8e6b090a637948c14358f02bcc28/image_2018-11-11.tiff
# Year: 2018 - week: 47
# Requested week slot: 11/18/2018 - 11/25/2018
# Ended downloading
# image_2018-11-18
# ./data/2018/887c46efc615d66b56a6b4b9e976dc4b/response.tiff renamed to ./data/2018/887c46efc615d66b56a6b4b9e976dc4b/image_2018-11-18.tiff
# Year: 2018 - week: 48
# Requested week slot: 11/25/2018 - 12/02/2018
# Ended downloading
# image_2018-11-25
# ./data/2018/eb9b0a3beeb4995c80c92220acec57ea/response.tiff renamed to ./data/2018/eb9b0a3beeb4995c80c92220acec57ea/image_2018-11-25.tiff
# Year: 2018 - week: 49
# Requested week slot: 12/02/2018 - 12/09/2018
# Ended downloading
# image_2018-12-02
# ./data/2018/f6212e8e78fb95aa8aaff00532c868fb/response.tiff renamed to ./data/2018/f6212e8e78fb95aa8aaff00532c868fb/image_2018-12-02.tiff
# Year: 2018 - week: 50
# Requested week slot: 12/09/2018 - 12/16/2018
# Ended downloading
# image_2018-12-09
# ./data/2018/5b3899b21f4b5b64f0f647fe03b0891c/response.tiff renamed to ./data/2018/5b3899b21f4b5b64f0f647fe03b0891c/image_2018-12-09.tiff
# Year: 2018 - week: 51
# Requested week slot: 12/16/2018 - 12/23/2018
# Ended downloading
# image_2018-12-16
# ./data/2018/2a923beb43c0c35ee80b7e2f4ab899f2/response.tiff renamed to ./data/2018/2a923beb43c0c35ee80b7e2f4ab899f2/image_2018-12-16.tiff
# Year: 2018 - week: 52
# Requested week slot: 12/23/2018 - 12/30/2018
# Ended downloading
# image_2018-12-23
# ./data/2018/03182914ef16ba187188adc2f8958625/response.tiff renamed to ./data/2018/03182914ef16ba187188adc2f8958625/image_2018-12-23.tiff

# %%
#shutil.rmtree("DATASET")
shutil.rmtree("data")

# %% [markdown]
# # Transfer to GCP bucket

# %%
from google.colab import auth
auth.authenticate_user()

project_id = 'mit-hst-dengue'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://colombia_sebasmos/
# gs://dsrestrepo/
# gs://mit-hst-dengue/

# %%
bucket_name = 'colombia_sebasmos'

# !gsutil -m cp -r /content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/ gs://{bucket_name}/
# Out:
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2015-11-01.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2015-11-08.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2015-11-22.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2015-11-15.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2015-11-29.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2015-12-20.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2015-12-13.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2015-12-06.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2015-12-27.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-01-03.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-01-10.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-01-17.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-01-24.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-01-31.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-02-07.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-02-14.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-02-21.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-02-28.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-03-06.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-03-13.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-03-20.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-04-03.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-03-27.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-04-10.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-04-17.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-05-01.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-04-24.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-05-08.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-05-15.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-05-22.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-05-29.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-06-05.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-06-12.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-06-19.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-06-26.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-07-03.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-07-10.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-07-17.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-07-24.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-07-31.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-08-07.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-08-21.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-08-28.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-08-14.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-09-11.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-09-18.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-09-04.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-09-25.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-10-02.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-10-09.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-10-16.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-10-23.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-10-30.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-11-13.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-11-06.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-11-27.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-11-20.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-12-18.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-12-11.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-12-25.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2016-12-04.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-01-01.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-01-08.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-01-29.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-01-15.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-01-22.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-02-05.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-02-12.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-02-19.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-02-26.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-03-05.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-03-12.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-03-19.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-03-26.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-04-02.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-04-16.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-04-23.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-04-30.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-05-07.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-04-09.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-05-14.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-05-21.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-05-28.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-06-11.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-06-04.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-06-18.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-06-25.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-07-02.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-07-09.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-07-16.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-07-23.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-08-06.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-07-30.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-08-13.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-08-20.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-08-27.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-09-03.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-09-10.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-09-17.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-10-08.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-10-15.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-09-24.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-10-01.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-11-05.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-10-29.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-10-22.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-11-19.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-11-12.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-11-26.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-12-10.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-12-03.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-12-17.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-12-24.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2017-12-31.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-01-21.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-01-28.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-01-14.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-02-04.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-01-07.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-02-18.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-02-25.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-03-04.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-02-11.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-03-11.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-03-18.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-03-25.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-04-01.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-04-08.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-04-15.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-04-22.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-04-29.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-05-20.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-05-13.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-05-06.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-05-27.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-06-03.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-06-10.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-06-24.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-06-17.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-07-01.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-07-08.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-07-15.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-07-22.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-07-29.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-08-05.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-08-12.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-08-19.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-08-26.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-09-02.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-09-16.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-09-09.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-09-23.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-09-30.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-10-07.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-10-14.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-11-04.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-10-21.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-10-28.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-11-11.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-11-18.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-11-25.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-12-02.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-12-09.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-12-16.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2015-11-01.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Cali/image_2018-12-23.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2015-11-15.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2015-11-08.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2015-11-22.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2015-11-29.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2015-12-13.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2015-12-06.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2015-12-20.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2015-12-27.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-01-03.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-01-10.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-01-17.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-01-24.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-02-07.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-02-14.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-02-21.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-01-31.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-02-28.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-03-06.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-03-13.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-03-20.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-04-03.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-03-27.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-04-10.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-04-24.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-04-17.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-05-01.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-05-15.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-05-08.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-05-29.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-05-22.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-06-05.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-06-19.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-06-26.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-06-12.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-07-03.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-07-10.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-07-17.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-07-31.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-07-24.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-08-07.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-08-14.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-08-21.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-08-28.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-09-04.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-09-11.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-09-18.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-10-09.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-10-02.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-09-25.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-10-16.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-11-06.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-11-13.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-10-30.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-10-23.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-11-20.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-11-27.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-12-04.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-12-11.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-12-18.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-01-01.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2016-12-25.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-01-08.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-01-22.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-01-29.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-01-15.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-02-05.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-02-12.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-03-05.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-02-19.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-02-26.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-03-19.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-03-12.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-04-02.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-03-26.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-04-09.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-04-16.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-04-23.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-04-30.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-05-07.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-05-21.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-05-28.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-05-14.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-06-11.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-06-04.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-07-02.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-07-09.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-06-18.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-06-25.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-07-16.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-08-13.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-08-20.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-07-23.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Medellín/image_2017-07-30.tiff [Content-Type=image/tiff]...
# ...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-05-14.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-05-21.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-05-28.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-06-11.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-06-04.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-06-18.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-06-25.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-07-02.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-07-09.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-07-16.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-07-23.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-08-06.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-07-30.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-08-13.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-09-03.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-08-27.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-08-20.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-09-10.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-09-17.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-09-24.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-10-01.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-10-08.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-10-15.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-10-29.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-10-22.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-11-12.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-11-05.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-11-26.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-11-19.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-12-24.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-12-03.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-12-10.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-12-31.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2017-12-17.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-01-07.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-01-14.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-01-21.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-01-28.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-02-04.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-02-11.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-02-18.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-02-25.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-03-11.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-03-04.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-03-18.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-03-25.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-04-01.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-04-08.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-04-15.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-04-22.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-04-29.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-05-06.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-05-13.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-05-20.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-05-27.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-06-03.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-06-10.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-06-17.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-06-24.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-07-01.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-07-08.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-07-15.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-07-29.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-08-05.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-07-22.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-08-12.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-08-19.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-08-26.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-09-02.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-09-09.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-09-16.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-09-23.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-09-30.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-10-07.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-10-14.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-10-21.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-11-04.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-11-11.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-11-18.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-10-28.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-11-25.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-12-02.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-12-09.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-12-16.tiff [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/Dengue_prediction/Codes_download_data_sentinel/satellite.extractor/DATASET_5_best_cities/Ibagué/image_2018-12-23.tiff [Content-Type=image/tiff]...
# | [825/825 files][  2.6 GiB/  2.6 GiB] 100% Done  34.9 MiB/s ETA 00:00:00
# Operation completed over 825 objects/2.6 GiB.

# %%
def plot_image(image, factor=1.0, clip_range = None, **kwargs):
    """
    Utility function for plotting RGB images.
    """
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 15))
    if clip_range is not None:
        ax.imshow(np.clip(image * factor, *clip_range), **kwargs)
    else:
        ax.imshow(image * factor, **kwargs)
    ax.set_xticks([])
    ax.set_yticks([])

# %%
images
# Out:
# ['./DATASET/Ibagué/image_2015-11-01.tiff',
#  './DATASET/Ibagué/image_2015-11-08.tiff',
#  './DATASET/Ibagué/image_2015-11-15.tiff',
#  './DATASET/Ibagué/image_2015-11-22.tiff',
#  './DATASET/Ibagué/image_2015-11-29.tiff',
#  './DATASET/Ibagué/image_2015-12-06.tiff',
#  './DATASET/Ibagué/image_2015-12-13.tiff',
#  './DATASET/Ibagué/image_2015-12-20.tiff',
#  './DATASET/Ibagué/image_2015-12-27.tiff',
#  './DATASET/Ibagué/image_2016-01-03.tiff',
#  './DATASET/Ibagué/image_2016-01-10.tiff',
#  './DATASET/Ibagué/image_2016-01-17.tiff',
#  './DATASET/Ibagué/image_2016-01-24.tiff',
#  './DATASET/Ibagué/image_2016-01-31.tiff',
#  './DATASET/Ibagué/image_2016-02-07.tiff',
#  './DATASET/Ibagué/image_2016-02-14.tiff',
#  './DATASET/Ibagué/image_2016-02-21.tiff',
#  './DATASET/Ibagué/image_2016-02-28.tiff',
#  './DATASET/Ibagué/image_2016-03-06.tiff',
#  './DATASET/Ibagué/image_2016-03-13.tiff',
#  './DATASET/Ibagué/image_2016-03-20.tiff',
#  './DATASET/Ibagué/image_2016-03-27.tiff',
#  './DATASET/Ibagué/image_2016-04-03.tiff',
#  './DATASET/Ibagué/image_2016-04-10.tiff',
#  './DATASET/Ibagué/image_2016-04-17.tiff',
#  './DATASET/Ibagué/image_2016-04-24.tiff',
#  './DATASET/Ibagué/image_2016-05-01.tiff',
#  './DATASET/Ibagué/image_2016-05-08.tiff',
#  './DATASET/Ibagué/image_2016-05-15.tiff',
#  './DATASET/Ibagué/image_2016-05-22.tiff',
#  './DATASET/Ibagué/image_2016-05-29.tiff',
#  './DATASET/Ibagué/image_2016-06-05.tiff',
#  './DATASET/Ibagué/image_2016-06-12.tiff',
#  './DATASET/Ibagué/image_2016-06-19.tiff',
#  './DATASET/Ibagué/image_2016-06-26.tiff',
#  './DATASET/Ibagué/image_2016-07-03.tiff',
#  './DATASET/Ibagué/image_2016-07-10.tiff',
#  './DATASET/Ibagué/image_2016-07-17.tiff',
#  './DATASET/Ibagué/image_2016-07-24.tiff',
#  './DATASET/Ibagué/image_2016-07-31.tiff',
#  './DATASET/Ibagué/image_2016-08-07.tiff',
#  './DATASET/Ibagué/image_2016-08-14.tiff',
#  './DATASET/Ibagué/image_2016-08-21.tiff',
#  './DATASET/Ibagué/image_2016-08-28.tiff',
#  './DATASET/Ibagué/image_2016-09-04.tiff',
#  './DATASET/Ibagué/image_2016-09-11.tiff',
#  './DATASET/Ibagué/image_2016-09-18.tiff',
#  './DATASET/Ibagué/image_2016-09-25.tiff',
#  './DATASET/Ibagué/image_2016-10-02.tiff',
#  './DATASET/Ibagué/image_2016-10-09.tiff',
#  './DATASET/Ibagué/image_2016-10-16.tiff',
#  './DATASET/Ibagué/image_2016-10-23.tiff',
#  './DATASET/Ibagué/image_2016-10-30.tiff',
#  './DATASET/Ibagué/image_2016-11-06.tiff',
#  './DATASET/Ibagué/image_2016-11-13.tiff',
#  './DATASET/Ibagué/image_2016-11-20.tiff',
#  './DATASET/Ibagué/image_2016-11-27.tiff',
#  './DATASET/Ibagué/image_2016-12-04.tiff',
#  './DATASET/Ibagué/image_2016-12-11.tiff',
#  './DATASET/Ibagué/image_2016-12-18.tiff',
#  './DATASET/Ibagué/image_2016-12-25.tiff',
#  './DATASET/Ibagué/image_2017-01-01.tiff',
#  './DATASET/Ibagué/image_2017-01-08.tiff',
#  './DATASET/Ibagué/image_2017-01-15.tiff',
#  './DATASET/Ibagué/image_2017-01-22.tiff',
#  './DATASET/Ibagué/image_2017-01-29.tiff',
#  './DATASET/Ibagué/image_2017-02-05.tiff',
#  './DATASET/Ibagué/image_2017-02-12.tiff',
#  './DATASET/Ibagué/image_2017-02-19.tiff',
#  './DATASET/Ibagué/image_2017-02-26.tiff',
#  './DATASET/Ibagué/image_2017-03-05.tiff',
#  './DATASET/Ibagué/image_2017-03-12.tiff',
#  './DATASET/Ibagué/image_2017-03-19.tiff',
#  './DATASET/Ibagué/image_2017-03-26.tiff',
#  './DATASET/Ibagué/image_2017-04-02.tiff',
#  './DATASET/Ibagué/image_2017-04-09.tiff',
#  './DATASET/Ibagué/image_2017-04-16.tiff',
#  './DATASET/Ibagué/image_2017-04-23.tiff',
#  './DATASET/Ibagué/image_2017-04-30.tiff',
#  './DATASET/Ibagué/image_2017-05-07.tiff',
#  './DATASET/Ibagué/image_2017-05-14.tiff',
#  './DATASET/Ibagué/image_2017-05-21.tiff',
#  './DATASET/Ibagué/image_2017-05-28.tiff',
#  './DATASET/Ibagué/image_2017-06-04.tiff',
#  './DATASET/Ibagué/image_2017-06-11.tiff',
#  './DATASET/Ibagué/image_2017-06-18.tiff',
#  './DATASET/Ibagué/image_2017-06-25.tiff',
#  './DATASET/Ibagué/image_2017-07-02.tiff',
#  './DATASET/Ibagué/image_2017-07-09.tiff',
#  './DATASET/Ibagué/image_2017-07-16.tiff',
#  './DATASET/Ibagué/image_2017-07-23.tiff',
#  './DATASET/Ibagué/image_2017-07-30.tiff',
#  './DATASET/Ibagué/image_2017-08-06.tiff',
#  './DATASET/Ibagué/image_2017-08-13.tiff',
#  './DATASET/Ibagué/image_2017-08-20.tiff',
#  './DATASET/Ibagué/image_2017-08-27.tiff',
#  './DATASET/Ibagué/image_2017-09-03.tiff',
#  './DATASET/Ibagué/image_2017-09-10.tiff',
#  './DATASET/Ibagué/image_2017-09-17.tiff',
#  './DATASET/Ibagué/image_2017-09-24.tiff',
#  './DATASET/Ibagué/image_2017-10-01.tiff',
#  './DATASET/Ibagué/image_2017-10-08.tiff',
#  './DATASET/Ibagué/image_2017-10-15.tiff',
#  './DATASET/Ibagué/image_2017-10-22.tiff',
#  './DATASET/Ibagué/image_2017-10-29.tiff',
#  './DATASET/Ibagué/image_2017-11-05.tiff',
#  './DATASET/Ibagué/image_2017-11-12.tiff',
#  './DATASET/Ibagué/image_2017-11-19.tiff',
#  './DATASET/Ibagué/image_2017-11-26.tiff',
#  './DATASET/Ibagué/image_2017-12-03.tiff',
#  './DATASET/Ibagué/image_2017-12-10.tiff',
#  './DATASET/Ibagué/image_2017-12-17.tiff',
#  './DATASET/Ibagué/image_2017-12-24.tiff',
#  './DATASET/Ibagué/image_2017-12-31.tiff',
#  './DATASET/Ibagué/image_2018-01-07.tiff',
#  './DATASET/Ibagué/image_2018-01-14.tiff',
#  './DATASET/Ibagué/image_2018-01-21.tiff',
#  './DATASET/Ibagué/image_2018-01-28.tiff',
#  './DATASET/Ibagué/image_2018-02-04.tiff',
#  './DATASET/Ibagué/image_2018-02-11.tiff',
#  './DATASET/Ibagué/image_2018-02-18.tiff',
#  './DATASET/Ibagué/image_2018-02-25.tiff',
#  './DATASET/Ibagué/image_2018-03-04.tiff',
#  './DATASET/Ibagué/image_2018-03-11.tiff',
#  './DATASET/Ibagué/image_2018-03-18.tiff',
#  './DATASET/Ibagué/image_2018-03-25.tiff',
#  './DATASET/Ibagué/image_2018-04-01.tiff',
#  './DATASET/Ibagué/image_2018-04-08.tiff',
#  './DATASET/Ibagué/image_2018-04-15.tiff',
#  './DATASET/Ibagué/image_2018-04-22.tiff',
#  './DATASET/Ibagué/image_2018-04-29.tiff',
#  './DATASET/Ibagué/image_2018-05-06.tiff',
#  './DATASET/Ibagué/image_2018-05-13.tiff',
#  './DATASET/Ibagué/image_2018-05-20.tiff',
#  './DATASET/Ibagué/image_2018-05-27.tiff',
#  './DATASET/Ibagué/image_2018-06-03.tiff',
#  './DATASET/Ibagué/image_2018-06-10.tiff',
#  './DATASET/Ibagué/image_2018-06-17.tiff',
#  './DATASET/Ibagué/image_2018-06-24.tiff',
#  './DATASET/Ibagué/image_2018-07-01.tiff',
#  './DATASET/Ibagué/image_2018-07-08.tiff',
#  './DATASET/Ibagué/image_2018-07-15.tiff',
#  './DATASET/Ibagué/image_2018-07-22.tiff',
#  './DATASET/Ibagué/image_2018-07-29.tiff',
#  './DATASET/Ibagué/image_2018-08-05.tiff',
#  './DATASET/Ibagué/image_2018-08-12.tiff',
#  './DATASET/Ibagué/image_2018-08-19.tiff',
#  './DATASET/Ibagué/image_2018-08-26.tiff',
#  './DATASET/Ibagué/image_2018-09-02.tiff',
#  './DATASET/Ibagué/image_2018-09-09.tiff',
#  './DATASET/Ibagué/image_2018-09-16.tiff',
#  './DATASET/Ibagué/image_2018-09-23.tiff',
#  './DATASET/Ibagué/image_2018-09-30.tiff',
#  './DATASET/Ibagué/image_2018-10-07.tiff',
#  './DATASET/Ibagué/image_2018-10-14.tiff',
#  './DATASET/Ibagué/image_2018-10-21.tiff',
#  './DATASET/Ibagué/image_2018-10-28.tiff',
#  './DATASET/Ibagué/image_2018-11-04.tiff',
#  './DATASET/Ibagué/image_2018-11-11.tiff',
#  './DATASET/Ibagué/image_2018-11-18.tiff',
#  './DATASET/Ibagué/image_2018-11-25.tiff',
#  './DATASET/Ibagué/image_2018-12-02.tiff',
#  './DATASET/Ibagué/image_2018-12-09.tiff',
#  './DATASET/Ibagué/image_2018-12-16.tiff',
#  './DATASET/Ibagué/image_2018-12-23.tiff']

# %%
from skimage import io
import numpy as np
import cv2

ncols = 4
nrows = 3
    
aspect_ratio = 1#coordinates_size[0] / coordinates_size[1]
subplot_kw = {'xticks': [], 'yticks': [], 'frame_on': False}
  
fig, axs = plt.subplots(ncols=ncols, nrows=nrows, figsize=(5 * ncols * aspect_ratio, 5 * nrows),
                            subplot_kw=subplot_kw)
    
for idx, path in enumerate(images):
        ax = axs[idx // ncols][idx % ncols]
        image = io.imread(path)
        image = np.array(image)
        image = image[:,:,1:4]
        ax.imshow(np.clip(image * 2.5/255, 0, 1))
        
plt.tight_layout()



# Move to structured folder in DATASETS
root_images_store = "." + root_images
dataset_store = "./" + city_str
for root, dirs, files in os.walk(root_images_store, topdown=True):
        for name in files:
          path = os.path.join(root, name)
          #print(path)
          if img_format in path and not dataset_store in path:
              shutil.copy(path, dataset_store)
              
images = glob.glob(dataset_store+"/*")
